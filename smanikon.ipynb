# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['smanikon']
# for each dataset
coll.insert_one ( { 'topic':'Social Media Usage and Imapct', '1st dataset': 'Most popular social media apps in the U.S. 2019', 'license': 'Statista 2019', 'description': 'popular mobile social networking apps in the United States by monthly users', 'urls': [ 'https://www.statista.com/statistics/248074/most-popular-us-social-networking-apps-ranked-by-audience/' ] } )
coll.insert_one ( { 'topic':'Social Media Usage and Imapct', '2nd dataset': 'Share of U.S. population who use social media 2008-20', 'license': 'Statista 2019', 'description': '%of US population who use social media from 2008-2019', 'urls': [ 'https://www.statista.com/statistics/273476/percentage-of-us-population-with-a-social-network-profile/'] } )
coll.insert_one ( { 'topic':'Social Media Usage and Imapct', '3rd dataset': 'An Analytical Study on Social Media Marketing and Online Presence of Brands', 'license': ' ResearchGate 2019', 'description': 'the impact of Social media marketing on communication turn into organizations marketing communications plans.', 'urls': [ 'https://www.researchgate.net/publication/258768950_An_Analytical_Study_on_Social_Media_Marketing_and_Online_Presence_of_Brands'] } )
coll.insert_one ( { 'topic':'Social Media Usage and Imapct', '4th dataset': 'NYC Social Media Usage', 'license': 'CC0: Public Domain', 'description': 'Social Media Usage using open data of NewYork City', 'urls': [ 'https://www.kaggle.com/new-york-city/nyc-social-media-usage' ] } )
coll.insert_one ( { 'topic':'Social Media Usage and Imapct', '5th dataset': 'Understanding Police Social Media Usage Through Posts and Tweets', 'license': 'CC0', 'description': 'measuring social media use by government agencies or other organizations', 'urls': [ 'shorturl.at/htKOR' ] } )
coll.insert_one ( { 'topic':'Social Media Usage and Imapct', '6th dataset': 'The impact of social media on attitudes towards farm animal welfare', 'license': 'CC BY 4.0 Mendley Data', 'description': 'the effects of social media on attitudes towards farm animal welfare FAW', 'urls': [ 'https://data.mendeley.com/datasets/cs7kmcfxtg/1' ] } )
coll.insert_one ( { 'topic':'Social Media Usage and Imapct', '7th dataset': 'Global impact of social media on daily life 2019', 'license': 'Statista 2019', 'description': 'social media platforms have had an impact on selected aspects of daily life', 'urls': [ 'https://www.statista.com/statistics/1015131/impact-of-social-media-on-daily-life-worldwide/' ] } )
coll.insert_one ( { 'topic':'Social Media Usage and Imapct', '8th dataset': 'Negative social media effects on teenagers', 'license': 'Statista 2019', 'description': 'Negative social media effects on teenagers in the USA as of April 2018, by emotional well-being', 'urls': [ 'https://www.statista.com/statistics/934121/negative-social-media-effects-usa-teenagers-emotional-well-being/' ] } )
coll.insert_one ( { 'topic':'Social Media Usage and Imapct', '9th dataset': 'Social impact in social media', 'license': 'creativecommons', 'description': 'To identify the potential or real social impact of research shared on social media, specifically on Twitter and Facebook.', 'urls': [ 'https://plos.figshare.com/articles/Social_impact_in_social_media_A_new_method_to_evaluate_the_social_impact_of_research/7025222' ] } )
coll.insert_one ( { 'topic':'Social Media Usage and Imapct', '10th dataset': 'Journalists views on the impact of social media ', 'license': 'Statista 2019', 'description': 'the impact of social media use on Journalists work in the United States in 2016', 'urls': [ 'https://www.statista.com/statistics/315891/journalists-views-impact-social-media-usa/' ] } )
coll.insert_one ( { 'topic':'Social Media Usage and Imapct', '11th dataset': 'Teen perspectives on positive effects of social media in the U.S. 2018', 'license': 'Statista 2019', 'description': 'Leading reasons why teenagers in the US feel that social media has a mostly positive effect on people their own age, April 2018', 'urls': [ 'https://www.statista.com/statistics/234570/perceived-effect-of-social-media-on-the-emotional-well-being-of-us-teens/' ] } )
coll.insert_one ( { 'topic':'Social Media Usage and Imapct', '12th dataset': 'Social Media: The New Window to Athlete’s Soul', 'license': 'NA', 'description': 'how social media has an impact on athlete’s performance', 'urls': [ 'https://www.kaggle.com/appliedresearcher/social-media-the-new-window-to-athletes-soul' ] } )
coll.insert_one ( { 'topic':'Social Media Usage and Imapct', '13th dataset': 'Social media impact on purchasing according to U.S. teens 2013', 'license': 'Statista 2019', 'description': 'Social media impact on purchasing according to teens, in 2013, USA', 'urls': [ 'https://www.statista.com/statistics/294459/social-media-shopping-impact-us-teens/'] } )
coll.insert_one ( { 'topic':'Social Media Usage and Imapct', '14th dataset': 'Effects of communication technology on relationships in France 2014', 'license': 'Statista 2019', 'description': 'Extent of the impact of technology on relationships with family and friends in France 2014', 'urls': [ 'https://www.statista.com/statistics/417739/impact-of-technology-family-friends-relationships-france/' ] } )
coll.insert_one ( { 'topic':'Social Media Usage and Imapct', '15th dataset': 'Reliability of news due to impact of social media worldwide 2013', 'license': 'Statista 2019', 'description': 'Does social media make news less reliable because journalists do less or no fact checking', 'urls': [ 'https://www.statista.com/statistics/315907/journalists-reliable-fact-checking-social-media-worldwide/' ] } )
coll.insert_one ( { 'topic':'Social Media Usage and Imapct', '16th dataset': 'Survey on impact of social media on companies in Denmark 2017', 'license': 'Statista 2019', 'description': 'the impact of social media on companies', 'urls': [ 'https://www.statista.com/statistics/744209/survey-on-impact-of-social-media-on-companies-in-denmark/' ] } )
coll.insert_one ( { 'topic':'Social Media Usage and Imapct', '17th dataset': 'Huawei Social Network Data', 'license': 'CC BY-NC-SA 4.0', 'description': 'Social Media Analysis Helps the Huawei Company to improve their businesses ', 'urls': [ 'https://www.kaggle.com/andrewlucci/huawei-social-network-data' ] } )
coll.insert_one ( { 'topic':'Social Media Usage and Imapct', '18th dataset': 'How social media services affect the lives of young people in Finland 2016', 'license': 'Statista 2019', 'description': 'How social media services affect the lives of young people in Finland in 2016', 'urls': [ 'https://www.statista.com/statistics/602118/effect-of-social-media-on-the-life-of-young-people-in-finland/' ] } )
coll.insert_one ( { 'topic':'Social Media Usage and Imapct', '19th dataset': 'Preferred social networks of U.S. teens 2012-2019', 'license': 'Statista 2019', 'description': 'Most popular social networks of teenagers in the United States from fall 2012 to spring 2019', 'urls': [ 'https://www.statista.com/statistics/250172/social-network-usage-of-us-teens-and-young-adults/' ] } )
coll.insert_one ( { 'topic':'Social Media Usage and Imapct', '20th dataset': 'How News Appears on Social Media', 'license': 'NA', 'description': 'Comparing Whats on Twitter and Reddit to Whats Happening in the World', 'urls': [ 'https://www.kaggle.com/socialmedianews/how-news-appears-on-social-media'] } )

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['smanikon']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'1st dataset': 'Most popular social media apps in the U.S. '
#                 '2019',
#  '_id': ObjectId('5d884a04b0978d880b173ccd'),
#  'description': 'popular mobile social networking apps in the '
#                 'United States by monthly users',
#  'license': 'Statista 2019',
#  'topic': 'Social Media Usage and Imapct',
#  'urls': ['https://www.statista.com/statistics/248074/most-popular-us-social-networking-apps-ranked-by-audience/']}
# {'2nd dataset': 'Share of U.S. population who use social media '
#                 '2008-20',
#  '_id': ObjectId('5d884a04b0978d880b173cce'),
#  'description': '%of US population who use social media from '
#                 '2008-2019',
#  'license': 'Statista 2019',
#  'topic': 'Social Media Usage and Imapct',
#  'urls': ['https://www.statista.com/statistics/273476/percentage-of-us-population-with-a-social-network-profile/']}
# {'3rd dataset': 'An Analytical Study on Social Media Marketing '
# ...
