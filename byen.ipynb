# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['audris']
# for each dataset
coll.insert_one ( { 'topic':'git URLs', 'first dataset': 'largest projects', 'license': 'NA', 'description': 'The list of projects on github with the largest number of starts', 'urls': [ 'url1', 'url2' ] } )

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['audris']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d7e6769e1eaff62f15de0d2'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
#  'urls': ['url1', 'url2']}
# {'_id': ObjectId('5d7edc7c995d246453e1025b'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
#  'urls': ['url1', 'url2']}
# {'_id': ObjectId('5d81827493569c62818e7979'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
#  'urls': ['url1', 'url2']}
# {'_id': ObjectId('5d8193ebd4732fb4def4810e'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
# ...

# %%
import pprint
import re
import pymongo, json
import pprint

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['byen']

# for each dataset
coll.insert_one({'topic': 'song lyrics', 'title': '55000+ Song Lyrics', 'license': 'CC0: Public Domain', 'description': 'Lyrics for 55000+ songs in English from LyricsFreak', 'urls': ['https://www.kaggle.com/mousehead/songlyrics']})
coll.insert_one({'topic': 'song lyrics', 'title': 'Song Lyrics', 'license': 'CC0: Public Domain', 'description': 'Lyric for 55000+ songs in English from LyricsFreak', 'urls': ['https://www.kaggle.com/paultimothymooney/poetry']})
coll.insert_one({'topic': 'song lyrics', 'title': 'Billboard 1964-2015 Songs + Lyrics', 'license': 'other', 'description': '50 Years of Pop Music Lyrics', 'urls': ['https://www.kaggle.com/rakannimer/billboard-lyrics']})
coll.insert_one({'topic': 'song lyrics', 'title': 'Song lyrics from 6 musical genres', 'license': 'unknown', 'description': 'Data scraped from the website vagalume.com.br', 'urls': ['https://www.kaggle.com/neisse/scrapped-lyrics-from-6-genres']})
coll.insert_one({'topic': 'song lyrics', 'title': 'FiveThirtyEight Hip Hop Candidate Lyrics Dataset', 'license': 'CC0: Public Domain', 'description': 'Hip Hop Candidate Lyrics', 'urls': ['https://www.kaggle.com/fivethirtyeight/fivethirtyeight-hip-hop-candidate-lyrics-dataset']})
coll.insert_one({'topic': 'song lyrics', 'title': 'Lyrics of best-selling artists', 'license': 'unknown', 'description': 'This dataset includes the lyrics of best-selling English artists of all time.', 'urls': ['https://www.kaggle.com/rkritika1508/lyrics-of-bestselling-artists']})
coll.insert_one({'topic': 'song lyrics', 'title': 'Kanye West Discography', 'license': 'CC0: Public Domain', 'description': 'Albums, songs and lyrics', 'urls': ['https://www.kaggle.com/slickwilly/kanye-west-discography']})
coll.insert_one({'topic': 'song lyrics', 'title': 'Every song you have heard (almost)!', 'license': 'Database: Open Database, Contents: Database Contents', 'description': 'Over 500,000 song lyrics, urls for over a million artists', 'urls': ['https://www.kaggle.com/artimous/every-song-you-have-heard-almost']})
coll.insert_one({'topic': 'song lyrics', 'title': 'Bollywood Lyrics Labelled', 'license': 'Unknown', 'description': 'Lyrics of 1291 bollywood songs.', 'urls': ['https://www.kaggle.com/adityktkr/bollywood-lyrics-labelled']})
coll.insert_one({'topic': 'song lyrics', 'title': 'Brazilian Songs Lyrics', 'license': 'Unknown', 'description': 'Brazilian Songs Lyrics', 'urls': ['https://www.kaggle.com/jorgefjr/brazilian-songs-lyrics']})
coll.insert_one({'topic': 'song lyrics', 'title': 'Indonesian song lyrics', 'license': 'CC BY 4.0', 'description': 'This dataset contains 400 Indonesian song lyrics. Each of 100 data are tagged as "children", "teenager", "adult", and "all-age" class.', 'urls': ['https://data.mendeley.com/datasets/jsd8rfdgch/1']})
coll.insert_one({'topic': 'song lyrics', 'title': 'lyrics', 'license': 'Unknown', 'description': 'No description yet', 'urls': ['https://www.kaggle.com/alipala/lyrics']})
coll.insert_one({'topic': 'song lyrics', 'title': 'Hamilton Lyrics', 'license': 'Unknown', 'description': 'A dataset containing lyrics to the Broadway musical \'Hamilton\'', 'urls': ['https://inclass.kaggle.com/lbalter/hamilton-lyrics']})
coll.insert_one({'topic': 'song lyrics', 'title': 'Chance the Rapper Lyrics', 'license': 'CC0: Public Domain', 'description': 'Find out what words Chance uses in his albums over time! (Hint: calculate log odds ratios after tokenizing!)', 'urls': ['https://www.kaggle.com/anm431/chance-the-rapper-lyrics']})
coll.insert_one({'topic': 'song lyrics', 'title': 'Atlanta Hip Hop Lyric Locations', 'license': 'CC0', 'description': 'A dataset including coordinates of locations in and around Atlanta mentioned in hip hop songs. This is by no means comprehensive, but it\'s a start', 'urls': ['https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/L1X5SW']})
coll.insert_one({'topic': 'song lyrics', 'title': 'Coldplay_Lyrics', 'license': 'Unknown', 'description': 'No description yet', 'urls': ['https://www.kaggle.com/kpriyanshu256/coldplay-lyrics']})
coll.insert_one({'topic': 'song lyrics', 'title': 'RushLyrics', 'license': 'Unknown', 'description': 'Lyrics for studio albums (1974-2013) from the Canadian band Rush. Dataset contains year of release, album number, album title, song name, and lyrics.', 'urls': ['https://www.kaggle.com/williamhipson/rushlyrics']})
coll.insert_one({'topic': 'song lyrics', 'title': 'Panic! at the Dataset', 'license': 'CC0: Public Domain', 'description': 'Why not?', 'urls': ['https://www.kaggle.com/theriley106/panic-at-the-dataset']})
coll.insert_one({'topic': 'song lyrics', 'title': 'The Italian Music Dataset', 'license': 'http://creativecommons.org/licenses/by/4.0/legalcode', 'description': 'The dataset is built by exploiting the Spotify and SoundCloud APIs', 'urls': ['https://zenodo.org/record/1298556#.XX7lzihKhPY','https://figshare.com/articles/The_Italian_Music_Dataset/6697700']})
coll.insert_one({'topic': 'song lyrics', 'title': 'Bro-Country: Is It Really New?', 'license': 'CC0', 'description': 'This is a content analysis comparison of the objectification of women in country music between 1993-1994 and 2013-2014. Today has been named an era of "bro country" where the music is dominated by sexually driven men. This study found that this era of "bro country" is new. Women are objectified in music much more today than they were 20 years ago; the number of songs about lust nearly doubled and the percentage of mention of physical appearance nearly quadrupled. Songs from the Billboard Top Ten charts were coded and analyzed; I focused on the gender of the artist, the theme of the song, and mention of physical appearance. This study is based in the Gender Dominance Theory which claims that men will objectify women and lessen their worth as a result of the empowerment of society’s heteronormativity. Country music today is much more objectifying than it was 1990s, therefore this "bro country" era is new. (2014-12-01)', 'urls': ['https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/2UCUQ4']})

pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d87b6bf995d246453e102a6'),
#  'description': 'Lyrics for 55000+ songs in English from '
#                 'LyricsFreak',
#  'license': 'CC0: Public Domain',
#  'title': '55000+ Song Lyrics',
#  'topic': 'song lyrics',
#  'urls': ['https://www.kaggle.com/mousehead/songlyrics']}
# {'_id': ObjectId('5d87b6bf995d246453e102a7'),
#  'description': 'Lyric for 55000+ songs in English from '
#                 'LyricsFreak',
#  'license': 'CC0: Public Domain',
#  'title': 'Song Lyrics',
#  'topic': 'song lyrics',
#  'urls': ['https://www.kaggle.com/paultimothymooney/poetry']}
# {'_id': ObjectId('5d87b6bf995d246453e102a8'),
#  'description': '50 Years of Pop Music Lyrics',
#  'license': 'other',
#  'title': 'Billboard 1964-2015 Songs + Lyrics',
#  'topic': 'song lyrics',
#  'urls': ['https://www.kaggle.com/rakannimer/billboard-lyrics']}
# {'_id': ObjectId('5d87b6bf995d246453e102a9'),
#  'description': 'Data scraped from the website vagalume.com.br',
#  'license': 'unknown',
# ...
