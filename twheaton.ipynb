# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['twheaton']
# for each dataset
coll.insert_one ( { 'topic':'git URLs', 'first dataset': 'largest projects', 'license': 'NA', 'description': 'The list of projects on github with the largest number of starts', 'urls': [ 'url1', 'url2' ] } )
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   # This is added back by InteractiveShellApp.init_path()
# ObjectId('5d7e6769e1eaff62f15de0d2')

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['twheaton']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d7e6769e1eaff62f15de0d2'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
#  'urls': ['url1', 'url2']}

# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['twheaton']
# for each dataset
coll.insert_one ( { 'topic':'NBA Statistics', 'title': 'Lineups', 'license': 'NA', 'description': 'List of starting lineups and rosters for NBA teams', 'urls': [ 'https://www.lineups.com/nba/lineups', 'http://www.espn.com/nba/players' ] } )
coll.insert_one ( { 'topic':'NBA Statistics', 'title': 'Steal Leaders', 'license': 'NA', 'description': 'List of top steal leaders in NBA with AVG steals per game and Top steals in total ', 'urls': [ 'https://www.espn.com/nba/stats/player/_/table/defensive/sort/avgSteals/dir/desc', 'http://www.espn.com/nba/history/leaders/_/stat/steals'] } )
coll.insert_one ( { 'topic':'NBA Statistics', 'title': 'Scoring Leaders', 'license': 'NA', 'description': 'List of top scorers in NBA', 'urls': [ 'https://en.wikipedia.org/wiki/List_of_National_Basketball_Association_career_scoring_leaders' ] } )
coll.insert_one ( { 'topic':'NBA Statistics', 'title': 'NBA Teams with Most Championships', 'license': 'NA', 'description': 'List of NBA teams with Championship Wins', 'urls': [ 'https://www.chatsports.com/nba/a/which-nba-team-has-won-most-championships-33626#/' ] } )
coll.insert_one ( { 'topic':'NBA Statistics', 'title': 'NBA Players with Most Championships', 'license': 'NA', 'description': 'Number of Championships from each player in the NBA', 'urls': [ 'https://en.wikipedia.org/wiki/List_of_NBA_players_with_most_championships' ] } )
coll.insert_one ( { 'topic':'NBA Statistics', 'title': 'NBA 2018-2019 Stat Leaders', 'license': 'NA', 'description': 'Short lists of top 5 NBA players in each statistic', 'urls': [ 'https://www.espn.com/nba/stats' ] } )
coll.insert_one ( { 'topic':'NBA Statistics', 'title': 'NBA Schedule', 'license': 'NA', 'description': 'List of upcoming NBA Games and Full Schedule', 'urls': [ 'https://stats.nba.com/schedule/' ] } )
coll.insert_one ( { 'topic':'NBA Statistics', 'title': 'NBA Draft Statistics', 'license': 'NA', 'description': 'Statistics on the NBA players looking to be drafted to the NBA', 'urls': [ 'https://stats.nba.com/draft/combine/', 'https://www.basketball-reference.com/draft/NBA_2019.html' ] } )
coll.insert_one ( { 'topic':'NBA Statistics', 'title': '2019 NBA Championship Statistics', 'license': 'NA', 'description': 'Infographic showing key statistics from the 2019 NBA Finals', 'urls': [ 'https://stats.nba.com/finals/' ] } )
coll.insert_one ( { 'topic':'NBA Statistics', 'title': '2018 NBA Championship Statistics', 'license': 'NA', 'description': 'Statistics from the NBA Finals in 2018', 'urls': [ 'https://www.basketball-reference.com/playoffs/2018-nba-finals-cavaliers-vs-warriors.html' ] } )
coll.insert_one ( { 'topic':'NBA Statistics', 'title': 'Lebron James Statistics', 'license': 'NA', 'description': 'Lebron James Statistics', 'urls': [ 'https://www.basketball-reference.com/players/j/jamesle01.html' ] } )
coll.insert_one ( { 'topic':'NBA Statistics', 'title': 'Michael Jordan Statistics', 'license': 'NA', 'description': 'Michael Jordans Statistics', 'urls': [ 'https://www.basketball-reference.com/players/j/jordami01.html' ] } )
coll.insert_one ( { 'topic':'NBA Statistics', 'title': 'Cleveland Cavaliers Statistics', 'license': 'NA', 'description': 'List of Clevelands NBA Team Statistics', 'urls': [ 'https://www.foxsports.com/nba/cleveland-cavaliers-team-stats' ] } )
coll.insert_one ( { 'topic':'NBA Statistics', 'title': 'Chicago Bulls Statistics', 'license': 'NA', 'description': 'Chicago Bulls Team Stats', 'urls': [ 'https://www.espn.com/nba/team/stats/_/name/chi/chicago-bulls' ] } )
coll.insert_one ( { 'topic':'NBA Statistics', 'title': 'Larry Bird Statistics', 'license': 'NA', 'description': 'All of Larry Birds Statistics', 'urls': [ 'https://www.basketball-reference.com/players/b/birdla01.html' ] } )
coll.insert_one ( { 'topic':'NBA Statistics', 'title': 'Allen Iverson Statistics', 'license': 'NA', 'description': 'A list of all of Allen Iversons statistics', 'urls': [ 'https://www.basketball-reference.com/players/i/iversal01.html' ] } )
coll.insert_one ( { 'topic':'NBA Statistics', 'title': 'Steve Nash Statistics', 'license': 'NA', 'description': 'List of all Steve Nashs statistics', 'urls': [ 'https://www.basketball-reference.com/players/n/nashst01.html' ] } )
coll.insert_one ( { 'topic':'NBA Statistics', 'title': 'Top Rebounders in NBA History', 'license': 'NA', 'description': 'List of all rebound leaders in NBA history', 'urls': [ 'http://www.espn.com/nba/history/leaders/_/stat/rebounds' ] } )
coll.insert_one ( { 'topic':'NBA Statistics', 'title': 'NBA Dunk Contest Winners', 'license': 'NA', 'description': 'List of all the NBA All Star Dunk Contest Winners and Scores', 'urls': [ 'https://www.nba.com/history/all-star/slam-dunk-contest' ] } )
coll.insert_one ( { 'topic':'NBA Statistics', 'title': 'NBA 3 Point Contest Winners', 'license': 'NA', 'description': 'List of all the NBA 3 Point Contest Winners and Scores', 'urls': [ 'https://www.nba.com/allstar/2019/events/three-point-contest' ] } )

pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print('-----------------------------------------------------------------------------' + '\n\n' + pp .pformat (r) + '\n')
# Out:
# -----------------------------------------------------------------------------
#
# {'_id': ObjectId('5d7e9c3be2400555609bd6f2'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
#  'urls': ['url1', 'url2']}
#
# -----------------------------------------------------------------------------
#
# {'_id': ObjectId('5d7e9f7ee2400555609bd6f4'),
#  'description': 'List of starting lineups and rosters for NBA '
#                 'teams',
#  'license': 'NA',
#  'title': 'NBA Lineups',
#  'topic': 'NBA Statistics',
#  'urls': ['https://www.lineups.com/nba/lineups',
#           'http://www.espn.com/nba/players']}
#
# -----------------------------------------------------------------------------
#
# {'_id': ObjectId('5d7e9f7ee2400555609bd6f5'),
#  'description': 'List of starting lineups and rosters for NBA '
#                 'teams',
#  'license': 'NA',
# ...
