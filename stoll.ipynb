# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['stoll']

coll.drop()

#Dataset Insertion
#1
coll.insert_one ( { 'topic':'Global Temperatures', 'title': 'Climate Change: Earth Surface Temperature Data', 
                   'license': 'CC BY-NC-SA 4.0', 'description': 'Global temperatures since 1750', 
                   'urls': [ 'https://www.kaggle.com/berkeleyearth/climate-change-earth-surface-temperature-data'] } )
#2
coll.insert_one ( { 'topic':'Global Temperatures', 'title': 'Berkeley Earth Surface Temperatures (BEST)', 
                   'license': 'N/A', 'description': 'Global temperatures since 1701 (and more)', 
                   'urls': [ 'https://climatedataguide.ucar.edu/climate-data/global-surface-temperatures-best-berkeley-earth-surface-temperatures'] } )
#3
coll.insert_one ( { 'topic':'Global Temperatures', 'title': 'Global Temperature Time Series', 
                   'license': 'PDDL', 'description': 'Global temperature data from GISTEMP and GCAG', 
                   'urls': [ 'https://public.opendatasoft.com/explore/dataset/global-temperature-time-series/table/'] } )
#4
coll.insert_one ( { 'topic':'Global Temperatures', 'title': 'NASA GISS Global Temperature', 
                   'license': 'N/A', 'description': 'Goddard Institute for Space Studies Surface Temperature Analysis -- Land-Ocean Temperature Index (LOTI)', 
                   'urls': [ 'https://data.world/agriculture/nasa-giss-global-temperature'] } )
#5
coll.insert_one ( { 'topic':'Global Temperatures', 'title': 'NASA Goddard\'s Global Surface Temperature Analysis (GISTEMP)', 
                   'license': 'N/A', 'description': 'Global temperatures since 1880', 
                   'urls': [ 'https://climatedataguide.ucar.edu/climate-data/global-surface-temperature-data-gistemp-nasa-goddard-institute-space-studies-giss'] } )
#6
coll.insert_one ( { 'topic':'Global Temperatures', 'title': 'Global Surface Temperature Data: HADCRUT4 and CRUTEM4', 
                   'license': 'N/A', 'description': 'Global temperatures since 1850 (and more)', 
                   'urls': [ 'https://climatedataguide.ucar.edu/climate-data/global-surface-temperature-data-hadcrut4-and-crutem4'] } )
#7
coll.insert_one ( { 'topic':'Global Temperatures', 'title': 'Global Climate Change Data', 
                   'license': 'N/A', 'description': 'Global Climate Change Data from 1750－2015', 
                   'urls': [ 'https://data.world/data-society/global-climate-change-data'] } )
#8
coll.insert_one ( { 'topic':'Global Temperatures', 'title': 'NOAA Global Surface Temperature Dataset, Version 4.0', 
                   'license': 'N/A', 'description': 'Combination of two independent analyses: the Extended Reconstructed Sea Surface Temperature (ERSST) analysis and the land surface temperature (LST) analysis using the Global Historical Climatology Network (GHCN) temperature database', 
                   'urls': [ 'https://data.nodc.noaa.gov/cgi-bin/iso?id=gov.noaa.ncdc:C00934'] } )
#9
coll.insert_one ( { 'topic':'Global Temperatures', 'title': 'MLOST: NOAA Merged Land-Ocean Surface Temperature Analysis', 
                   'license': 'N/A', 'description': 'Global temperatures since 1871 + Global Historical Climatology Network, Monthly (GHCN-M) data', 
                   'urls': [ 'https://climatedataguide.ucar.edu/climate-data/global-surface-temperature-data-mlost-noaa-merged-land-ocean-surface-temperature'] } )
#10
coll.insert_one ( { 'topic':'Global Temperatures', 'title': 'Historical global temperature analysis', 
                   'license': 'https://creativecommons.org/licenses/by/4.0/', 'description': 'Gridded monthly mean temperature anomalies', 
                   'urls': [ 'https://figshare.com/articles/Historical_global_temperature_analysis/8040668'] } )
#11
coll.insert_one ( { 'topic':'Global Temperatures', 'title': 'Climate Prediction Center (CPC) Global Temperature Time Series', 
                   'license': 'U.S. Government Work', 'description': ' Time series charts using station based observations of daily temperature', 
                   'urls': [ 'https://catalog.data.gov/dataset/climate-prediction-center-cpc-global-temperature-time-series'] } )
#12
coll.insert_one ( { 'topic':'Global Temperatures', 'title': 'Climate Warming - Global Summer Temperature Scenario: 2050', 
                   'license': 'Open Government Licence - Canada', 'description': 'Simulation of projected changes in June to August mean temperatures from the period 1975 to 1995 to the period 2040 to 2060', 
                   'urls': [ 'https://open.canada.ca/data/en/dataset/eab11a00-8893-11e0-9b17-6cf049291510'] } )
#13
coll.insert_one ( { 'topic':'Global Temperatures', 'title': 'International Surface Temperature Initiative (ISTI) Global Land Surface Temperature Databank - Stage 3 Monthly', 
                   'license': 'N/A', 'description': 'Monthly timescale mean, maximum, and minimum temperature for approximately 40,000 stations globally', 
                   'urls': [ 'https://data.nodc.noaa.gov/cgi-bin/iso?id=gov.noaa.ncdc:C00849'] } )
#14
coll.insert_one ( { 'topic':'Global Temperatures', 'title': 'State of the Climate - Global Analysis', 
                   'license': 'N/A', 'description': 'Collection of periodic summaries recapping climate-related occurrences on both a global and national scale', 
                   'urls': [ 'https://data.nodc.noaa.gov/cgi-bin/iso?id=gov.noaa.ncdc:C00672'] } )
#15
coll.insert_one ( { 'topic':'Global Temperatures', 'title': 'GHCN-D: Global Historical climatology Network daily temperatures', 
                   'license': 'N/A', 'description': 'Meteorological measurements from over 90,000 stations across the globe', 
                   'urls': [ 'https://climatedataguide.ucar.edu/climate-data/ghcn-d-global-historical-climatology-network-daily-temperatures'] } )
#16
coll.insert_one ( { 'topic':'Global Temperatures', 'title': 'Global (land) precipitation and temperature: Willmott & Matsuura, University of Delaware', 
                   'license': 'N/A', 'description': 'Series of gridded temperature and precipitation data sets', 
                   'urls': [ 'https://climatedataguide.ucar.edu/climate-data/global-land-precipitation-and-temperature-willmott-matsuura-university-delaware'] } )
#17
coll.insert_one ( { 'topic':'Global Temperatures', 'title': 'Global Temp & Greenhouse Gas', 
                   'license': 'Public Domain', 'description': 'Analysis of CO2\'s role as in Climate Change through the lens of time series data', 
                   'urls': [ 'https://data.world/amschwinn/global-temp-greenhouse-gas'] } )
#18
coll.insert_one ( { 'topic':'Global Temperatures', 'title': 'Estimation of sea surface temperatures and salinity of ODP Site 177-1089 (Appendix A)', 
                   'license': 'https://creativecommons.org/licenses/by/3.0/', 'description': 'Sea surface temperatures circa 1997', 
                   'urls': [ 'https://doi.pangaea.de/10.1594/PANGAEA.712940'] } )
#19
coll.insert_one ( { 'topic':'Global Temperatures', 'title': 'HadCRUT4: gridded dataset of global historical surface temperature anomalies. Version 4.4.0.0', 
                   'license': 'http://www.nationalarchives.gov.uk/doc/non-commercial-government-licence/non-commercial-government-licence.htm', 'description': 'Blend of the CRUTEM4 land-surface air temperature dataset and the HadSST3 sea-surface temperature (SST) dataset', 
                   'urls': [ 'https://catalogue.ceda.ac.uk/uuid/b347afd27083431480739e3b07945327'] } )
#20
coll.insert_one ( { 'topic':'Global Temperatures', 'title': 'Ocean temperature analysis and heat content estimate from Institute of Atmospheric Physics', 
                   'license': 'N/A', 'description': 'Ocean temperature analysis that features global coverage of the oceans, at 1° x1° horizontal resolution on 41 vertical levels from 1-2000m, and monthly resolution from 1940 to present', 
                   'urls': [ 'https://climatedataguide.ucar.edu/climate-data/ocean-temperature-analysis-and-heat-content-estimate-institute-atmospheric-physics'] } )

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['stoll']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d87b22b14cca008a56e916b'),
#  'description': 'Global temperatures since 1750',
#  'license': 'CC BY-NC-SA 4.0',
#  'title': 'Climate Change: Earth Surface Temperature Data',
#  'topic': 'Global Temperatures',
#  'urls': ['https://www.kaggle.com/berkeleyearth/climate-change-earth-surface-temperature-data']}
# {'_id': ObjectId('5d87b22b14cca008a56e916c'),
#  'description': 'Global temperatures since 1701 (and more)',
#  'license': 'N/A',
#  'title': 'Berkeley Earth Surface Temperatures (BEST)',
#  'topic': 'Global Temperatures',
#  'urls': ['https://climatedataguide.ucar.edu/climate-data/global-surface-temperatures-best-berkeley-earth-surface-temperatures']}
# {'_id': ObjectId('5d87b22b14cca008a56e916d'),
#  'description': 'Global temperature data from GISTEMP and GCAG',
#  'license': 'PDDL',
#  'title': 'Global Temperature Time Series',
#  'topic': 'Global Temperatures',
# ...
