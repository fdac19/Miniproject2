# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['alnidu']
# for each dataset
coll.insert_one ( { 'topic':'Pokemon', 'first dataset': 'pokemon.com', 'license': 'CC0: Public Domain', 'description': 'This data set includes 721 Pokemon, including their number, name, first and second type, and basic stats: HP, Attack, Defense, Special Attack, Special Defense, and Speed. It has been of great use when teaching statistics to kids.', 'urls': [ 'https://www.kaggle.com/abcsds/pokemon','https://public-us.opendatasoft.com/explore/dataset/pokemon-with-stats/' ] } )
coll.insert_one ( { 'topic':'Pokemon', 'first dataset': ' http://serebii.net/', 'license': 'CC0: Public Domain', 'description': 'This dataset contains information on all 802 Pokemon from all Seven Generations of Pokemon.', 'urls': [ 'https://www.kaggle.com/rounakbanik/pokemon' ] } )
coll.insert_one ( { 'topic':'Pokemon', 'first dataset': '', 'license': 'GPL 2', 'description': 'The dataset was built out of necessity as there was not much sanitised data available online for images of Pokemon based on their Generation and names', 'urls': [ 'https://www.kaggle.com/thedagger/pokemon-generation-one' ] } )
coll.insert_one ( { 'topic':'Pokemon', 'first dataset': 'https://www.kaggle.com/abcsds/pokemon', 'license': 'CC BY-NC-SA 4.0', 'description': 'With the rise of the popularity of machine learning, this is a good opportunity to share a wide database of the even more popular video-game Pokémon by Nintendo, Game freak, and Creatures, originally released in 1996.', 'urls': [ 'https://www.kaggle.com/alopez247/pokemon' ] } )
coll.insert_one ( { 'topic':'Pokemon', 'first dataset': 'Kaggle dataset.', 'license': 'NA', 'description': 'Gotta Catch em All!', 'urls': [ 'https://data.world/ljvmiranda921/pokemon-go-dataset' ] } )
coll.insert_one ( { 'topic':'Pokemon', 'first dataset': 'PokemonDB.net', 'license': 'Public Domain', 'description': 'Contains attack, defense, speed, and HP stats for all Pokemon numbered 1-718 and their special forms.', 'urls': [ 'https://data.world/steveinatx/pokemon-index' ] } )
coll.insert_one ( { 'topic':'Pokemon', 'first dataset': 'Kaggle dataset', 'license': 'NA', 'description': 'This data set includes 721 Pokemon, including their number, name, first and second type, and basic stats: HP, Attack, Defense, Special Attack, Special Defense, and Speed', 'urls': [ 'https://data.world/data-society/pokemon-with-stats' ] } )
coll.insert_one ( { 'topic':'Pokemon', 'first dataset': '', 'license': 'CC0: Public Domain', 'description': 'Welcome to Weedle s cave. Will you be able to predict the outcome of future matches?', 'urls': [ 'https://www.kaggle.com/terminus7/pokemon-challenge' ] } )
coll.insert_one ( { 'topic':'Pokemon', 'first dataset': 'QUBES', 'license': 'custom', 'description': 'These are resources associated with using Pokemon Go to teach concepts in Ecology.', 'urls': [ 'https://qubeshub.org/qubesresources/publications/787' ] } )
coll.insert_one ( { 'topic':'Pokemon', 'first dataset': 'Statista', 'license': 'NA', 'description': 'The timeline presents the estimated annual revenues generated by Pokémon Go worldwide from 2016 to 2020, broken down by region.', 'urls': [ 'https://www.statista.com/statistics/665623/revenue-from-pokemon-go-global-region/' ] } )
coll.insert_one ( { 'topic':'Pokemon', 'first dataset': 'Statista', 'license': 'NA', 'description': 'In July 2016, an augmented reality gaming phenomenon hit our smartphone screens. Pokémon GO had players roaming around parks and streets in the real world in an attempt to capture, train and battle their virtual Pokémon. ', 'urls': [ 'https://www.statista.com/statistics/665640/pokemon-go-global-android-apple-users/' ] } )
coll.insert_one ( { 'topic':'Pokemon', 'first dataset': 'University of California, Davis', 'license': 'http://creativecommons.org/publicdomain/zero/1.0/legalcode', 'description': 'Free to use for educators and researchers hoping to use the Pokémon to teach evolution, phylogenetics, etc. ', 'urls': [ 'https://zenodo.org/record/61631' ] } )
coll.insert_one ( { 'topic':'Pokemon', 'first dataset': 'kasabi', 'license': 'CC BY-SA', 'description': 'Location of Google Pokemon Challenge s pokemons. Gotta Catch Em All!', 'urls': [ 'https://public.opendatasoft.com/explore/dataset/pokedex_clean/' ] } )
coll.insert_one ( { 'topic':'Pokemon', 'first dataset': 'Triply Academy', 'license': 'http://creativecommons.org/licenses/by-sa/3.0/', 'description': 'Link to the presentation on Creating Knowledge Graphs. Link to the presentation on Querying Knowledge Graphs.', 'urls': [ 'https://triplydb.com/academy/pokemon' ] } )
coll.insert_one ( { 'topic':'Pokemon', 'first dataset': 'PLOS ONE', 'license': 'https://creativecommons.org/licenses/by/4.0/', 'description': 'Pokemon (POK erythroid myeloid ontogenic factor), which belongs to the POK protein family, is also called LRF, OCZF and FBI-1.', 'urls': [ 'https://plos.figshare.com/articles/The_Silencing_of_Pokemon_Attenuates_the_Proliferation_of_Hepatocellular_Carcinoma_Cells_In_Vitro_and_In_Vivo_by_Inhibiting_the_PI3K_Akt_Pathway__/115306' ] } )
coll.insert_one ( { 'topic':'Pokemon', 'first dataset': 'Harvard Dataverse', 'license': 'CC0', 'description': 'Preliminary study: Pokemon GO and physical activity among a group of university students', 'urls': [ 'https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/AMUDOG' ] } )
coll.insert_one ( { 'topic':'Pokemon', 'first dataset': 'Data.World, Inc.', 'license': 'CC0', 'description': 'Smogon 6v6 is one of the most popular formats for competitive Pokemon. Although it is not the "official" competitive format, there is still a significant number of people who play the format. ', 'urls': [ 'https://data.world/notgibs/smogon-6-v-6-pokemon-tiers' ] } )
coll.insert_one ( { 'topic':'Pokemon', 'first dataset': 'Data.World, Inc.', 'license': '', 'description': 'The list of projects on github with the largest number of starts', 'urls': [ 'url1', 'url2' ] } )
coll.insert_one ( { 'topic':'Pokemon', 'first dataset': 'ADLRO', 'license': 'NA', 'description': 'Performance sports and sedentary lifestyle are two sides of the same coin', 'urls': [ 'https://search.datacite.org/works/10.12753/2066-026X-17-153?resource-type-id=dataset' ] } )
coll.insert_one ( { 'topic':'Pokemon', 'first dataset': 'Kaggle', 'license': 'GPL 2', 'description': 'With the recent release of Pokemon Lets Go!, I wanted to do some kind of learning project related to pictures of Pokemon. ', 'urls': [ 'https://www.kaggle.com/brkurzawa/original-150-pokemon-image-search-results' ] } )

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['alnidu']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d8450c93db540142a277253'),
#  'description': 'This data set includes 721 Pokemon, including '
#                 'their number, name, first and second type, and '
#                 'basic stats: HP, Attack, Defense, Special '
#                 'Attack, Special Defense, and Speed. It has '
#                 'been of great use when teaching statistics to '
#                 'kids.',
#  'first dataset': 'pokemon.com',
#  'license': 'CC0: Public Domain',
#  'topic': 'Pokemon',
#  'urls': ['https://www.kaggle.com/abcsds/pokemon',
#           'https://public-us.opendatasoft.com/explore/dataset/pokemon-with-stats/']}
# {'_id': ObjectId('5d8450c93db540142a277254'),
#  'description': 'This dataset contains information on all 802 '
#                 'Pokemon from all Seven Generations of Pokemon.',
#  'first dataset': ' http://serebii.net/',
#  'license': 'CC0: Public Domain',
#  'topic': 'Pokemon',
#  'urls': ['https://www.kaggle.com/rounakbanik/pokemon']}
# ...
