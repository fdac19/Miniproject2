# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['jlambers']
# for each dataset
coll.insert_one ( { 'topic':'rivers', 'first dataset': 'USA Rivers and Streams', 'license': 'Esri Mater License Agreement', 'description': 'A list of rivers and streams in the US. Includes data such as the state (USA) the river is in and length.', 'urls': [ 'http://hub.arcgis.com/datasets/esri::usa-rivers-and-streams'] } )
coll.insert_one ( { 'topic':'rivers', 'second dataset': 'National River Flow Archive Peak Flow Dataset', 'license': 'NRFA Data Terms and Conditions for access to time-series data and metadata', 'description': 'Hydrometric peak flow data about river flow in the UK.', 'urls': [ 'https://nrfa.ceh.ac.uk/peak-flow-dataset'] } )
coll.insert_one ( { 'topic':'rivers', 'third dataset': 'Risk of Floooding From Rivers and Sea', 'license': 'Open Government License', 'description': 'A grid of flood likelihood for rivers in the UK.', 'urls': [ 'https://data.gov.uk/dataset/bad20199-6d39-4aad-8564-26a46778fd94/risk-of-flooding-from-rivers-and-sea'] } )
coll.insert_one ( { 'topic':'rivers', 'fourth dataset': 'Allegheny County Major Rivers', 'license': 'Public License', 'description': 'A hydrological dataset about the rivers in Allegheny County, PA', 'urls': [ 'https://catalog.data.gov/dataset/allegheny-county-major-rivers-480ba'] } )
coll.insert_one ( { 'topic':'rivers', 'fifth dataset': 'Chalk Rivers', 'license': 'Open Government License', 'description': 'A low resolution indicative trace of chalk rivers and streams created from OS maps.', 'urls': [ 'https://data.gov.uk/dataset/f478556e-9eb5-4d4a-a0c6-78654860ebda/chalk-rivers'] } )

coll.insert_one ( { 'topic':'rivers', 'sixth dataset': 'Hunter Main Rivers and Tributaries Catchment Areas', 'license': 'Creative Commons Attribution 4.0', 'description': 'Contains the area in square kilometers for a variety of rivers, brooks, and creeks in Hunter Australia', 'urls': [ 'https://data.gov.au/data/dataset/b58a1799-a1c6-42b0-8827-fedc506c8f7a'] } )

coll.insert_one ( { 'topic':'rivers', 'seventh dataset': 'City of West Sacramento Rivers', 'license': 'As-Is License', 'description': 'Major creeks in the Sacramento Region', 'urls': [ 'http://datahub.cityofwestsacramento.org/datasets/f9642247cc814861a65b96148f696631_0'] } )

coll.insert_one ( { 'topic':'rivers', 'eighth dataset': 'CLM - Tidal and Non-Tidal Rivers', 'license': 'Creative Commons Attribution 4.0', 'description': 'Shows river reaches that are tidal and river reaches that are non-tidal in the Richmond and Clarence riverbasins of NSW', 'urls': [ 'https://data.gov.au/data/dataset/c391f212-90cf-4aba-bcd2-64c7460462b0'] } )

coll.insert_one ( { 'topic':'rivers', 'ninth dataset': 'Rivers of Florida', 'license': 'None Specified', 'description': 'River location and attributes in Florida.', 'urls': [ 'http://geodata.myflorida.com/datasets/ca12b8fa7ce6479d83f4d844c65ebbf5_2'] } )

coll.insert_one ( { 'topic':'rivers', 'tenth dataset': 'Main Rivers of Wales', 'license': 'Open Government License', 'description': 'A 110,000 scale spatial dataset that defines statutory watercourses designated by Natural Resources Wales as main rivers.', 'urls': [ 'https://data.gov.uk/dataset/a3650b47-2ae6-42fb-b0ea-c06664993a9e/main-rivers#licence-info'] } )

coll.insert_one ( { 'topic':'rivers', 'eleventh dataset': 'Biochemical Oxygen Demand in Rivers', 'license': 'None Specified', 'description': 'Shows the biochemical oxygen demand in rivers of Europe.', 'urls': [ 'http://data.europa.eu/euodp/data/dataset/rYsd2bjHKGttQApfJr4GRA'] } )

coll.insert_one ( { 'topic':'rivers', 'twelfth dataset': 'Historical Transportation of Navigable Rivers, Canals, and Railroads in the United States', 'license': 'ICPSR 36353', 'description': 'Collection of GIS materials that cover different modes of transportation in the lower 48 states from Americas founding through about 1911.', 'urls': [ 'https://www.icpsr.umich.edu/icpsrweb/ICPSR/studies/36353'] } )

coll.insert_one ( { 'topic':'rivers', 'thirteenth dataset': 'Freeze-Up and Break-Up of Rivers and Lakes', 'license': 'Open Government License - Canada', 'description': 'Contains four maps that show the mean freeze-over date, among other attributes, for rivers and lakes in canada.', 'urls': [ 'https://open.canada.ca/data/en/dataset/dd663e71-272b-5b47-8300-c8b749ea70bb'] } )

coll.insert_one ( { 'topic':'rivers', 'fourtheenth dataset': 'Rivers and Streams Georgia', 'license': 'Creative Commons 4.0', 'description': 'Shows the rivers and streams in the state of Georgia.', 'urls': [ 'https://opendata.atlantaregional.com/datasets/b508b692d2d245dbb0510bcb56878ab6_29'] } )

coll.insert_one ( { 'topic':'rivers', 'fifteenth dataset': 'Rivers Pant, Blackwater and Finchingfield Brook Survey', 'license': 'Creative Commons CCZero', 'description': 'Former National Rivers Authority paper records for river corridor surveys of the River Blackwater, River Pant, and Finchingfield Brook in Essex.', 'urls': [ 'https://data.gov.uk/dataset/5d037e51-28e8-4cc1-918b-f093d785ec34/rivers-pant-blackwater-and-finchingfield-brook-survey'] } )

coll.insert_one ( { 'topic':'rivers', 'sixteenth dataset': 'Rivers and Streams in the Atlanta Region', 'license': 'Creative Commons 4.0', 'description': 'Contains linear hydrographic features and their attributes from the Atlanta, GA area.', 'urls': [ 'https://opendata.atlantaregional.com/datasets/1d4cb4e279c5485c95e1385769c9b723_28'] } )

coll.insert_one ( { 'topic':'rivers', 'seventeenth dataset': 'Gloucester River Types V03', 'license': 'Restricted Access: Not For Public Distribution', 'description': 'Contains river types shapefiles that describe rivers according to the Gloucester Assessment Extent.', 'urls': [ 'https://data.gov.au/data/dataset/d9810dea-78e3-4c81-9ba0-6d0172d4c248'] } )

coll.insert_one ( { 'topic':'rivers', 'eighteenth dataset': 'River Styles Spatial Layer for New South Wales', 'license': 'Creative Commons Attribution 3.0', 'description': 'Shows the pattern and connectivity of reaches of different river style within the context of catchment-scale controls.', 'urls': [ 'https://data.gov.au/data/dataset/06fb694b-d2f1-4338-ab65-a707c02f11d7'] } )

coll.insert_one ( { 'topic':'rivers', 'nineteenth dataset': 'Urban and Foothill Ridge to River Trails', 'license': 'Custom License from City of Boise', 'description': 'City of Boise Parks and Recreation trail data. Includes data about trails that lead to rivers.', 'urls': [ 'http://opendata.cityofboise.org/datasets/25eedd01c4e0404ea0f235d9033d2715_0'] } )

coll.insert_one ( { 'topic':'rivers', 'twentieth dataset': 'Rivers in Colombia', 'license': 'Creative Commons Attribution 4.0', 'description': 'Contains shape data about the rivers in Colombia.', 'urls': [ 'https://datacatalog.worldbank.org/dataset/rivers-colombia'] } )

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['jlambers']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d899787eb89a1ba1b15e17b'),
#  'description': 'A list of rivers and streams in the US. '
#                 'Includes data such as the state (USA) the '
#                 'river is in and length.',
#  'first dataset': 'USA Rivers and Streams',
#  'license': 'Esri Mater License Agreement',
#  'topic': 'rivers',
#  'urls': ['http://hub.arcgis.com/datasets/esri::usa-rivers-and-streams']}
# {'_id': ObjectId('5d899787eb89a1ba1b15e17c'),
#  'description': 'Hydrometric peak flow data about river flow in '
#                 'the UK.',
#  'license': 'NRFA Data Terms and Conditions for access to '
#             'time-series data and metadata',
#  'second dataset': 'National River Flow Archive Peak Flow '
#                    'Dataset',
#  'topic': 'rivers',
#  'urls': ['https://nrfa.ceh.ac.uk/peak-flow-dataset']}
# {'_id': ObjectId('5d899787eb89a1ba1b15e17d'),
#  'description': 'A grid of flood likelihood for rivers in the '
#                 'UK.',
# ...
