# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['roffutt']
# for each dataset

coll.insert_one ( { 'topic':'west Nile virus', 'title': 'NNDSS - Table II. West Nile virus disease', 'license': 'NA', 'description': 'provisional cases of selected notifiable diseases and selected low frequency diseases are displayed', 'urls': [ 'https://catalog.data.gov/dataset/nndss-table-ii-west-nile-virus-disease-5bf9d'] } )
coll.insert_one ( { 'topic':'west Nile virus', 'title': 'NNDSS - Table II. Varicella to West Nile virus disease', 'license': 'NA', 'description': ' all conditions with a 5-year average annual national total of more than or equals 1,000 cases but less than or equals 10,000 cases will be displayed', 'urls': [ 'https://catalog.data.gov/dataset/nndss-table-ii-varicella-to-west-nile-virus-disease'] } )
coll.insert_one ( { 'topic':'west Nile virus', 'title': 'West Nile Virus (WNV) Mosquito Test Results', 'license': 'NA', 'description': ' List of locations and test results for pools of mosquitoes tested through the Chicago Department of Public Health Environmental Health program', 'urls': [ 'https://catalog.data.gov/dataset/wnv-mosquito-test-results-42116'] } )
coll.insert_one ( { 'topic':'west Nile virus', 'title': 'NNDSS - TABLE 1D. Arboviral diseases, West Nile virus to Babesiosis', 'license': 'NA', 'description': 'provisional cases* of notifiable diseases are displayed for United States, U.S. territories, and Non-U.S. residents', 'urls': [ 'https://data.cdc.gov/NNDSS/NNDSS-TABLE-1D-Arboviral-diseases-West-Nile-virus-/fc5f-ixvg'] } )
coll.insert_one ( { 'topic':'west Nile virus', 'title': 'West Nile Virus Cases', 'license': 'NA', 'description': 'This dataset contains positive cases of West Nile virus found in humans by county of residence, 2006-present. ', 'urls': [ 'https://data.world/health/west-nile-virus-cases'] } )

coll.insert_one ( { 'topic':'west Nile virus', 'title': 'West Nile Virus Cases, 2006-present', 'license': 'CHHS Open Data Portal Terms of Use specific', 'description': 'This dataset contains positive cases of West Nile virus found in humans by county of residence, 2006-present', 'urls': [ 'https://data.chhs.ca.gov/dataset/west-nile-virus-cases-2006-present'] } )
coll.insert_one ( { 'topic':'west Nile virus', 'title': 'West Nile virus infection data', 'license': 'NA', 'description': 'The dataset provides surveillance and disease data for West Nile virus infection.', 'urls': [ 'http://data.europa.eu/euodp/data/dataset/west-nile-fever-data'] } )
coll.insert_one ( { 'topic':'west Nile virus', 'title': 'CA West Nile Virus Cases', 'license': 'NA', 'description': 'This dataset contains positive cases of West Nile virus found in humans by county of residence, 2006-present. ', 'urls': [ 'https://data.world/healthdata/ca-west-nile-virus-cases'] } )
coll.insert_one ( { 'topic':'west Nile virus', 'title': 'Mosquito and West Nile virus monitoring program', 'license': 'NA', 'description': 'n 2004, in cooperation with USGS in Fort Collins, a monitoring study was established to assess the level of occurrence and potential effects of WNV on wild raptor populations', 'urls': [ 'https://data.doi.gov/dataset/mosquito-and-west-nile-virus-monitoring-program'] } )
coll.insert_one ( { 'topic':'west Nile virus', 'title': 'West Nile Virus', 'license': 'NA', 'description': 'This map shows the average annual incidence of neuroinvasive West Nile virus disease in each state, which is calculated as the average number of new cases per 100,000 people per year from 2002 to 2015. ', 'urls': [ 'https://hub.arcgis.com/datasets/42e3cfab020b4c7286fbe09aad59a331'] } )

coll.insert_one ( { 'topic':'west Nile virus', 'title': 'Manitoba West Nile Virus Surveillance Map - 2019', 'license': 'NA', 'description': 'This web map is an overview of the Manitoba West Nile Virus (WNV) surveillance program results for the current year.', 'urls': [ 'https://hub.arcgis.com/datasets/bec39c54c36941efb06041a87e7aac4c'] } )
coll.insert_one ( { 'topic':'west Nile virus', 'title': 'Data_Sheet_1_Human West Nile Virus Disease Outbreak in Pakistan, 2015–2016.XLSX', 'license': 'NA', 'description': 'Human WNV cases and vector numbers exhibited a temporal correlation with climate', 'urls': [ 'https://figshare.com/articles/Data_Sheet_1_XLSX/5926846/1'] } )
coll.insert_one ( { 'topic':'west Nile virus', 'title': 'Mosquito-borne diseases in the U.S. - Statistics & Facts', 'license': 'NA', 'description': 'Different regions are impacted by different mosquito-borne diseases depending on climate, the types of mosquitoes common in the region, and access to preventative measures and medicin', 'urls': [ 'https://www.statista.com/topics/4264/mosquito-borne-diseases-in-the-us/'] } )
coll.insert_one ( { 'topic':'west Nile virus', 'title': 'Light pollution increases West Nile virus competence of a ubiquitous passerine reservoir species', 'license': 'NSF license', 'description': 'Light pollution increases West Nile virus competence of a ubiquitous passerine reservoir species, v2, ', 'urls': [ 'https://datadryad.org/stash/dataset/doi:10.5061/dryad.7v72n64'] } )
coll.insert_one ( { 'topic':'west Nile virus', 'title': 'A spatio-temporal individual-based network framework for West Nile virus in the USA: Spreading pattern of West Nile virus', 'license': ' open access article, free of all copyright', 'description': 'US Centers for Diseases Control and Prevention (CDC) has identified WNV infection in more than three hundred species of birds', 'urls': [ 'https://journals.plos.org/ploscompbiol/article?id=10.1371/journal.pcbi.1006875'] } )

coll.insert_one ( { 'topic':'west Nile virus', 'title': 'NNDSS - West Nile virus disease', 'license': 'NA', 'description': 'NNDSS - Table II. West Nile to Zika - 2018. ', 'urls': [ 'https://www.kaggle.com/cdc/nndss-west-nile-virus-disease'] } )
coll.insert_one ( { 'topic':'west Nile virus', 'title': 'Mosquitoes Inoculate High Doses of West Nile Virus as They Probe and Feed on Live Hosts', 'license': 'NA', 'description': 'The amount of WNV inoculated by mosquitoes as they feed on a live host is not known', 'urls': [ 'https://figshare.com/articles/Mosquitoes_Inoculate_High_Doses_of_West_Nile_Virus_as_They_Probe_and_Feed_on_Live_Hosts/151691/1'] } )
coll.insert_one ( { 'topic':'west Nile virus', 'title': 'Chicago West Nile Virus Mosquito Test Results', 'license': 'CC0: Public Domain', 'description': 'List of locations and test results for pools of mosquitoes tested through the Chicago Department of Public Health Environmental Health program', 'urls': [ 'https://www.kaggle.com/chicago/chicago-west-nile-virus-mosquito-test-results'] } )
coll.insert_one ( { 'topic':'west Nile virus', 'title': 'Serological, Molecular and Entomological Surveillance Demonstrates Widespread Circulation of West Nile Virus in Turkey', 'license': 'NA', 'description': 'ield-collected mosquitoes from 92 sites at 46 locations were characterized morphologically and evaluated for viral RNA.', 'urls': [ 'https://figshare.com/articles/_Serological_Molecular_and_Entomological_Surveillance_Demonstrates_Widespread_Circulation_of_West_Nile_Virus_in_Turkey_/1116689/1'] } )
coll.insert_one ( { 'topic':'west Nile virus', 'title': 'Access disease data from ECDC Surveillance Atlas - West Nile virus infection', 'license': 'European Commission reuse notice', 'description': 'Disease data from ECDC Surveillance Atlas - West Nile virus infection', 'urls': [ 'http://data.europa.eu/euodp/data/dataset/west-nile-fever-data/resource/128f91e7-eda6-471e-bf60-8a4b6c8221a6'] } )

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['roffutt']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d883357b25f5b8117ed7d80'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
#  'urls': ['url1', 'url2']}
# {'_id': ObjectId('5d883485b25f5b8117ed7d83'),
#  'description': 'provisional cases of selected notifiable '
#                 'diseases and selected low frequency diseases '
#                 'are displayed',
#  'license': 'NA',
#  'title': 'NNDSS - Table II. West Nile virus disease',
#  'topic': 'west Nile virus',
#  'urls': ['https://catalog.data.gov/dataset/nndss-table-ii-west-nile-virus-disease-5bf9d']}
# {'_id': ObjectId('5d88349bb25f5b8117ed7d86'),
#  'description': 'provisional cases of selected notifiable '
#                 'diseases and selected low frequency diseases '
#                 'are displayed',
#  'license': 'NA',
#  'title': 'NNDSS - Table II. West Nile virus disease',
#  'topic': 'west Nile virus',
# ...
