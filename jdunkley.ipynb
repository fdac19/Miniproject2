# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['jdunkley']
# for each dataset
coll.insert_one ( { 'topic':'EEG', 'title': 'Confused student EEG brainwave data', 'license': 'CC0: Public Domain', 'description': 'EEG data from 10 students watching MOOC videos', 'urls': [ 'https://www.kaggle.com/wanghaohan/confused-eeg#EEG_data.csv' ] } )
coll.insert_one ( { 'topic':'EEG', 'title': 'EEG and audio dataset for auditory attention decoding', 'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode', 'description': 'This dataset contains EEG recordings from 18 subjects listening to one of two competing speech audio streams.', 'urls': [ 'https://zenodo.org/record/1199011' ] } )
coll.insert_one ( { 'topic':'EEG', 'title': 'EEG During Mental Arithmetic Tasks', 'license': 'https://opendatacommons.org/licenses/by/index.html', 'description': 'The database contains EEG recordings of subjects before and during the performance of mental arithmetic tasks.', 'urls': [ 'https://physionet.org/content/eegmat/1.0.0/' ] } )
coll.insert_one ( { 'topic':'EEG', 'title': 'Newborn sleep EEG data', 'license': 'https://creativecommons.org/licenses/by/4.0/', 'description': 'The dataset includes 1,110 sleep EEG recorded in clinical conditions from newborns in 10 age groups from 36 to 45 weeks is available as MATLAB .mat files.', 'urls': [ 'https://figshare.com/articles/Newborn_sleep_EEG_data/4729840' ] } )
coll.insert_one ( { 'topic':'EEG', 'title': 'The original EEG data for driver fatigue detection', 'license': 'https://creativecommons.org/licenses/by/4.0/', 'description': 'The list of projects on github with the largest number of starts', 'urls': [ 'https://figshare.com/articles/The_original_EEG_data_for_driver_fatigue_detection/5202739' ] } )
coll.insert_one ( { 'topic':'EEG', 'title': 'CHB-MIT Scalp EEG Database', 'license': 'https://opendatacommons.org/licenses/by/index.html', 'description': 'This database, collected at the Children’s Hospital Boston, consists of EEG recordings from pediatric subjects with intractable seizures.', 'urls': [ 'https://physionet.org/content/chbmit/1.0.0/' ] } )
coll.insert_one ( { 'topic':'EEG', 'title': 'EEG and head motion data acquired simultaneously to fMRI data.', 'license': 'CC0', 'description': 'The data is composed of EEG data from three healthy subjects. The data were collected outside and inside the scanner.', 'urls': [ 'https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/LU58IU' ] } )
coll.insert_one ( { 'topic':'EEG', 'title': 'EEG proof of concept', 'license': 'CC0 1.0', 'description': 'A collection of 1 brain maps. Each brain map is a 3D array of values representing properties of the brain at different locations.', 'urls': [ 'https://neurovault.org/collections/89/' ] } )
coll.insert_one ( { 'topic':'EEG', 'title': 'Adolescent Sleep Need Waking EEG, Years 1-3', 'license': 'CC0', 'description': 'Data from the adolescent sleep need study examining the effect of prior time in bed on waking EEG activity', 'urls': [ 'https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/EVNUZS' ] } )
coll.insert_one ( { 'topic':'EEG', 'title': 'Data from: Using a structured-light 3D scanner to improve EEG source modeling with more accurate electrode positions', 'license': 'https://data.donders.ru.nl/doc/dua/RU-DI-HD-1.0.html', 'description': 'In this study, we evaluated the use of a structured-light 3D scanner for EEG electrode digitization. We tested its accuracy, robustness and evaluated its practical feasibility.', 'urls': [ 'https://data.donders.ru.nl/collections/di/dccn/DSC_3015055.01_493?0' ] } )
coll.insert_one ( { 'topic':'EEG', 'title': 'EEG Signals from an RSVP Task', 'license': 'https://opendatacommons.org/licenses/by/index.html', 'description': 'This project contains EEG data from 11 healthy participants upon rapid presentation of images through the Rapid Serial Visual Presentation (RSVP) protocol at speeds of 5, 6, and 10 Hz.', 'urls': [ 'https://physionet.org/content/ltrsvp/1.0.0/' ] } )
coll.insert_one ( { 'topic':'EEG', 'title': 'EEG Data Pre Stimulation/Sham (All Three Tasks)', 'license': 'https://creativecommons.org/licenses/by/4.0/', 'description': 'EEG signal data (20 channels) was acquired using a Quick-30 EEG headset (Cognionics Inc.) with data recorded using proprietary acquisition software.', 'urls': [ 'https://figshare.com/articles/EEG_Data_Pre_Stimulation_Sham_All_Three_Tasks_/7834847/1' ] } )
coll.insert_one ( { 'topic':'EEG', 'title': 'Effects of ON/OFF deep brain stimulation on cognitive control in treatment-resistant depression (EEG)', 'license': 'Unknown', 'description': 'Effects of ON/OFF deep brain stimulation on cognitive control (EEG) in severe depression', 'urls': [ 'https://openneuro.org/datasets/ds001784/versions/1.0.3' ] } )
coll.insert_one ( { 'topic':'EEG', 'title': 'Data from: A semi-simulated EEG/EOG dataset for the comparison of EOG artifact rejection techniques', 'license': 'CC BY 4.0', 'description': 'This work presents a semi-simulated EEG dataset, where artifact-free EEG signals are manually contaminated with ocular artifacts', 'urls': [ 'https://data.mendeley.com/datasets/wb6yvr725d/4' ] } )
coll.insert_one ( { 'topic':'EEG', 'title': 'EEG data for P300 speller', 'license': 'http://creativecommons.org/publicdomain/zero/1.0/legalcode', 'description': 'These EEG signals were recorded during a P300 speller paradigm.', 'urls': [ 'https://zenodo.org/record/30084' ] } )
coll.insert_one ( { 'topic':'EEG', 'title': 'EEG Alpha Waves dataset', 'license': 'http://creativecommons.org/licenses/by/4.0/legalcode', 'description': 'This dataset contains electroencephalographic recordings of subjects in a simple resting-state eyes open/closed experimental protocol.', 'urls': [ 'https://zenodo.org/record/2348892' ] } )
coll.insert_one ( { 'topic':'EEG', 'title': 'EEG files - Mu Suppression experiment', 'license': 'CC0', 'description': 'Raw EEG files (.CNT) from Mu Suppression experiment. These 65 files include the 61 participants retained in published analyses, and 4 who do not retain over 16 trials per condition (our threshold for retaining).', 'urls': [ 'https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/HMPGYN' ] } )
coll.insert_one ( { 'topic':'EEG', 'title': 'EEG data of simple and compound limb motor imagery', 'license': 'CC0', 'description': 'Original EEG data from ten subjects during simple and compound limb motor imagery.', 'urls': [ 'https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/27306' ] } )
coll.insert_one ( { 'topic':'EEG', 'title': 'Signal Processing Toolbox for Simultaneously Acquired fMRI and EEG', 'license': 'GNU General Public License 3.0', 'description': 'This Matlab toolbox includes signal processing functions to remove gradient and pulse artifacts in EEG data recorded simultaneously with fMRI. It is distributed as a GUI plugin for EEGLAB.', 'urls': [ 'https://purr.purdue.edu/publications/1936/2' ] } )
coll.insert_one ( { 'topic':'EEG', 'title': 'EEG/fMRI data recorded during T/A neurofeedback experiment', 'license': 'CC0', 'description': 'The dataset contains 15 mins data of 10 participants performing relaxation task guided by their T/A activity. The files contain the EEG data from electrode Pz and the BOLD-activity in the right amygdala.', 'urls': [ 'https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/TG4UKF' ] } )

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['jdunkley']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d87ec8af4f8006a2dbc5513'),
#  'description': 'EEG data from 10 students watching MOOC videos',
#  'license': 'CC0: Public Domain',
#  'title': 'Confused student EEG brainwave data',
#  'topic': 'EEG',
#  'urls': ['https://www.kaggle.com/wanghaohan/confused-eeg#EEG_data.csv']}
# {'_id': ObjectId('5d87ec8af4f8006a2dbc5514'),
#  'description': 'This dataset contains EEG recordings from 18 '
#                 'subjects listening to one of two competing '
#                 'speech audio streams.',
#  'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#  'title': 'EEG and audio dataset for auditory attention '
#           'decoding',
#  'topic': 'EEG',
#  'urls': ['https://zenodo.org/record/1199011']}
# {'_id': ObjectId('5d87ec8af4f8006a2dbc5515'),
#  'description': 'The database contains EEG recordings of '
#                 'subjects before and during the performance of '
#                 'mental arithmetic tasks.',
# ...
