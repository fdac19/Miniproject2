# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['nbranch']
# for each dataset
coll.insert_one ( { 'topic':'Most recognizable superheroes according to adults in the United States as of March 2019',
                   '15th dataset': 'Most recognizable superheroes according to adults in the United States as of March 2019 ', 
                   'license': 'NA', 
                   'description': 'Title says it all',
                   'urls': [ 'https://www.statista.com/statistics/989799/most-recognizable-superheros-us/'] } )

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['nbranch']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d88862bc42213a0957103fb'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
#  'urls': ['https://www.kaggle.com/fivethirtyeight/fivethirtyeight-comic-characters-dataset',
#           'url2']}
# {'_id': ObjectId('5d888630c42213a0957103fd'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
#  'urls': ['https://www.kaggle.com/fivethirtyeight/fivethirtyeight-comic-characters-dataset',
#           'url2']}
# {'_id': ObjectId('5d8887b2c42213a095710401'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
# ...
