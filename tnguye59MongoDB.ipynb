# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)
git
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['tnguye59']
# for each dataset
coll.insert_one ( { 'topic':'Sports Nutrition', 'first dataset': 'Effects of previous carbohydrate supplementation on muscular fatigue', 'license': 'NA', 'description': 'study on effect of carbohydrate intake before exercise', 'urls': [ 'http://www.scielo.br/scielo.php?script=sci_arttext&pid=S1980-65742019000100709&tlng=en' ] } )
coll.insert_one ( { 'topic':'Sports Nutrition', 'first dataset': 'Ingestion of High Molecular Weight Carbohydrate Enhances Subsequent Repeated Maximal Power', 'license': 'NA', 'description': 'study on high-carbohydrate intake for maximal power', 'urls': [ 'https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0163009' ] } )
coll.insert_one ( { 'topic':'Sports Nutrition', 'first dataset': 'Effect of protein and carbohydrate solutions on running performance and cognitive function in female recreational runners', 'license': 'NA', 'description': 'Study comparing effects of protein and carbohydrate sources on 21-km runners; physically and mentally', 'urls': [ 'https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0185982'] } )
coll.insert_one ( { 'topic':'Sports Nutrition', 'first dataset': 'Ingestion of a drink containing carbohydrate increases the number of bench press repetitions', 'license': 'NA', 'description': 'Study to see if bench press repetitions improve after drinking carbohydrate filled drink', 'urls': [ 'https://scielo.figshare.com/articles/Ingestion_of_a_drink_containing_carbohydrate_increases_the_number_of_bench_press_repetitions/8195267/1'] })
coll.insert_one ( { 'topic':'Sports Nutrition', 'first dataset': 'Efficacy and Safety of Whey Protein Supplements on Vital Sign and Physical Performance Among Athletes: A Network Meta-Analysis', 'license': 'NA', 'description': 'aimed to explore the clinical evidence on the efficacy and safety of WPS in sports performance and recovery among athletes.', 'urls': [ 'https://www.frontiersin.org/articles/10.3389/fphar.2019.00317/full'] })
coll.insert_one ( { 'topic':'Sports Nutrition', 'first dataset': 'Influence of Fish Oil-Derived n-3 Fatty Acid Supplementation on Changes in Body Composition and Muscle Strength During Short-Term Weight Loss in Resistance-Trained Men', 'license': 'NA', 'description': 'study aimed to investigate the influence of dietary n-3PUFA supplementation on changes in body composition and muscle strength following short-term diet-induced weight loss in resistance-trained men', 'urls': [ 'https://www.frontiersin.org/articles/10.3389/fnut.2019.00102/full'] })
coll.insert_one ( { 'topic':'Sports Nutrition', 'first dataset': 'Effects of taurine supplementation in elite swimmers performance', 'license': 'NA', 'description': 'study to evaluate the effects of taurine supplementation on the resting energy expenditure and physical performance of swimming athletes.', 'urls': [ 'https://figshare.com/articles/Effects_of_taurine_supplementation_in_elite_swimmers_performance/6008246/1'] })
coll.insert_one ( { 'topic':'Sports Nutrition', 'first dataset': 'Influence of food intake and use of supplements in performance of brazilian para-athlete', 'license': 'NA', 'description': 'Analyzing energy and protein consumption and the use of nutritional supplements in para-athletes in order to assess the influence of dietary strategy on performance', 'urls': [ 'https://scielo.figshare.com/articles/Influence_of_food_intake_and_use_of_supplements_in_performance_of_brazilian_para-athletes/7974521/1'] })
coll.insert_one ( { 'topic':'Sports Nutrition', 'first dataset': 'The Effect of Protandim® Supplementation on Athletic Performance and Oxidative Blood Markers in Runners', 'license': 'NA', 'description': 'study determined if oral supplementation of Protandim® (a nutraceutical) for 90 days improved 5-km running performance ', 'urls': [ 'https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0160559'] })
coll.insert_one ( { 'topic':'Sports Nutrition', 'first dataset': 'Pomegranate Supplementation Accelerates Recovery of Muscle Damage and Soreness and Inflammatory Markers after a Weightlifting Training Session', 'license': 'NA', 'description': 'investigate the effect of natural Pomegranate juice supplementation on performance and acute and delayed responses of muscle soreness and biomarkers of muscle damage after a weightlifting training session', 'urls': [ 'https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0160305'] })
coll.insert_one ( { 'topic':'Sports Nutrition', 'first dataset': 'Branched-Chain Amino Acids and Arginine Improve Performance in Two Consecutive Days of Simulated Handball Games in Male and Female Athletes', 'license': 'NA', 'description': 'investigate the effect of combined supplementation of branched-chain amino acids (BCAA) and arginine on intermittent sprint performance in simulated handball games on 2 consecutive days', 'urls': [ 'https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0121866'] })
coll.insert_one ( { 'topic':'Sports Nutrition', 'first dataset': 'Influence of a Polyphenol-Enriched Protein Powder on Exercise-Induced Inflammation and Oxidative Stress in Athletes', 'license': 'NA', 'description': 'Polyphenol supplementation was tested as a countermeasure to inflammation and oxidative stress induced by 3-d intensified training', 'urls': [ 'https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0072215'] })
coll.insert_one ( { 'topic':'Sports Nutrition', 'first dataset': 'Effect of the intake of high or low glycemic index high carbohydrate-meals on athletes’ sleep quality in pre-game nights', 'license': 'NA', 'description': 'study investigated the effect of the intake of high (HGI) or low glycemic index (LGI) high-carbohydrate meals on athletes’ sleep', 'urls': [ 'https://scielo.figshare.com/articles/Effect_of_the_intake_of_high_or_low_glycemic_index_high_carbohydrate-meals_on_athletes_sleep_quality_in_pre-game_nights/7973963/1'] })
coll.insert_one ( { 'topic':'Sports Nutrition', 'first dataset': 'MUSCLE STRENGTH AND CAFFEINE SUPPLEMENTATION', 'license': 'NA', 'description': 'examine in the current literature the advances made in terms of the effects of caffeine supplementation on maximum strength ', 'urls': [ 'https://scielo.figshare.com/articles/MUSCLE_STRENGTH_AND_CAFFEINE_SUPPLEMENTATION_ARE_WE_DOING_MORE_OF_THE_SAME_/7974962/1'] })
coll.insert_one ( { 'topic':'Sports Nutrition', 'first dataset': 'Effects of Graded Whey Supplementation During Extreme-Volume Resistance Training', 'license': 'NA', 'description': 'examined hypertrophic outcomes of weekly graded whey protein dosing (GWP) vs. whey protein (WP) or maltodextrin (MALTO) dosed once daily during 6 weeks of high-volume resistance training ', 'urls': [ 'https://www.frontiersin.org/articles/10.3389/fnut.2018.00084/full'] })
coll.insert_one ( { 'topic':'Sports Nutrition', 'first dataset': 'Effect of vitamin D supplementation on upper and lower limb muscle strength and muscle power in athletes', 'license': 'NA', 'description': 'quantitatively summarize the evidence for the effect of vitamin D supplementation on skeletal muscle strength and explosive power of athletes ', 'urls': [ 'https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0215826'] })
coll.insert_one ( { 'topic':'Sports Nutrition', 'first dataset': 'Powdered coconut water as hydroelectrolytic and energetic supplement for athletes', 'license': 'NA', 'description': 'evaluate a sports drink based on powdered coconut water, aiming at improving the performance of amateur and professional athletes ', 'urls': [ 'https://scielo.figshare.com/articles/Powdered_coconut_water_as_hydroelectrolytic_and_energetic_supplement_for_athletes/7974251/1'] })
coll.insert_one ( { 'topic':'Sports Nutrition', 'first dataset': 'Use of dietary and performance-enhancing supplements among male fitness center members in Riyadh', 'license': 'NA', 'description': 'study aimed to explore the health beliefs and patterns of dietary supplement usage among fitness center members', 'urls': [ 'https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0199289'] })

coll.insert_one ( { 'topic':'Sports Nutrition', 'first dataset': 'A Multi-Ingredient Containing Carbohydrate, Proteins L-Glutamine and L-Carnitine Attenuates Fatigue Perception with No Effect on Performance, Muscle Damage or Immunity in Soccer Players', 'license': 'NA', 'description': 'effects of ingesting a multi-ingredient (53g carbohydrate, 14.5g whey protein, 5g glutamine, 1.5g L-carnitine-L-tartrate) supplement, carbohydrate only, or placebo on intermittent performance, perception of fatigue, immunity, and functional and metabolic markers of recovery.', 'urls': [ 'https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0125188'] })
coll.insert_one ( { 'topic':'Sports Nutrition', 'first dataset': 'Intake of Protein Plus Carbohydrate during the First Two Hours after Exhaustive Cycling Improves Performance the following Day', 'license': 'NA', 'description': 'study was to compare performance 18 h after exhaustive cycling in a randomized diet-controlled study', 'urls': [ 'https://plos.figshare.com/articles/Intake_of_Protein_Plus_Carbohydrate_during_the_First_Two_Hours_after_Exhaustive_Cycling_Improves_Performance_the_following_Day/3948447'] })

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['tnguye59']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r),'\n')
# Out:
# {'_id': ObjectId('5d7f0242b8435a6603132661'),
#  'description': 'study on effect of carbohydrate intake before '
#                 'exercise',
#  'first dataset': 'Effects of previous carbohydrate '
#                   'supplementation on muscular fatigue',
#  'license': 'NA',
#  'topic': 'Sports Nutrition',
#  'urls': ['http://www.scielo.br/scielo.php?script=sci_arttext&pid=S1980-65742019000100709&tlng=en']}
#
# {'_id': ObjectId('5d7f0242b8435a6603132662'),
#  'description': 'study on high-carbohydrate intake for maximal '
#                 'power',
#  'first dataset': 'Ingestion of High Molecular Weight '
#                   'Carbohydrate Enhances Subsequent Repeated '
#                   'Maximal Power',
#  'license': 'NA',
#  'topic': 'Sports Nutrition',
#  'urls': ['https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0163009']}
#
# {'_id': ObjectId('5d7f0242b8435a6603132663'),
#  'description': 'Study comparing effects of protein and '
# ...
