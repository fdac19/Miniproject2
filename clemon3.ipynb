# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient(host="da1.eecs.utk.edu")
db = client['fdac19mp2']
coll = db['clemon3']
# for each dataset
# coll.insert_one ( { 'topic':'git URLs', 'first dataset': 'largest projects', 'license': 'NA', 'description': 'The list of projects on github with the largest number of starts', 'urls': [ 'url1', 'url2' ] } )
coll.insert_one({
    'topic': 'Golf',
    'title': 'PGA Tour Golf Data',
    'license': 'CC BY-NC-SA 4.0',
    'description': 'The datasets consist of all the statistics of all of the players on the PGA Tour from 2010 - August 25, 2019. The data will be updated weekly at the conclusion of each tournament. The most recent tournament in the 2019 data set is The Tour Championship.',
    'urls': [
        'https://www.kaggle.com/bradklassen/pga-tour-20102018-data'
    ]
})

coll.insert_one({
    'topic': 'Golf',
    'title': 'Golf Gear and Equipment Data',
    'license': 'N/A',
    'description': 'Golf Gear & Equipment performance statistics including transactions, price, conversion rate and top product categories.',
    'urls': [
        'https://www.jumpshot.com/category/sports-fitness-outdoors/golf'
    ]
})

coll.insert_one({
    'topic': 'Golf',
    'title': 'Golf Gear and Equipment Data',
    'license': 'N/A',
    'description': 'Golf Gear & Equipment performance statistics including transactions, price, conversion rate and top product categories.',
    'urls': [
        'https://www.jumpshot.com/category/sports-fitness-outdoors/golf'
    ]
})

coll.insert_one({
    'topic': 'Golf',
    'title': 'Locations of golf courses in the state of Hawaii',
    'license': 'N/A',
    'description': 'Locations of golf courses in the State of Hawaii as of October, 2014.',
    'urls': [
        'https://hub.arcgis.com/datasets/HiStateGIS::golf-courses'
    ]
})

coll.insert_one({
    'topic': 'Golf',
    'title': 'Locations of golf courses in the state of New York',
    'license': 'N/A',
    'description': 'The New York State Office of Parks, Recreation and Historic Preservation (OPRHP) oversees more than 214 state parks and historic sites, encompassing nearly 335,000 acres, that are visited by 60 million people annually. These facilities contribute to the economic vitality and quality of life of local communities and directly support New York’s tourism industry. Parks also provide a place for families and children to be active and exercise, promoting healthy lifestyles. The agency is responsible for the operation and stewardship of the state park system as well as advancing a statewide parks, historic preservation, and open space mission.From the famed Bethpage Black, to the rolling terrain of the Robert Trent Jones\' designed 18-hole course at Green Lakes State Park, New York\'s state park golf courses rank among the best public courses in the world.',
    'urls': [
        'https://catalog.data.gov/dataset/golf-courses',
        'https://data.amerigeoss.org/dataset/golf-courses'
    ]
})

#####

coll.insert_one({
    'topic': 'Golf',
    'title': 'Golf Fitness Training: Improving Swing with Core Training',
    'license': 'N/A',
    'description': 'The words core training, golf fitness, and improving the golf swing have become widespread words inside golfing. It is popular the quantity of expert golfers using a golf fitness system with enhance their golf swing. Addition for this well-known condition a usual word has become connected to the phrase golfing fitness. This phrase has become a buzzword inside the world of golf. Unfortunately countless do not recognize the phrase as well as the relevance it can wear the golf swing. The phrase is core training. Core training could be a excellent benefit with the golfing swing as a piece of comprehensive golfing fitness system.',
    'urls': [
        'https://old.datahub.io/dataset/golf_fitness_training_improves_your_golf_swing_with_core_training',
        'https://data.wu.ac.at/schema/datahub_io/YWFjYWI5ZTUtOGJiNi00ZjQ3LWE0MTUtN2ViYjQ3MWYzNDVm'
    ]
})

coll.insert_one({
    'topic': 'Golf',
    'title': 'Total Revenue for Golf Courses and Country Clubs, All Establishments, Employer Firms',
    'license': 'N/A',
    'description': 'Graph and download economic data for Total Revenue for Golf Courses and Country Clubs, All Establishments, Employer Firms (REVEF71391ALLEST) from 1998 to 2017 about sport, recreation, employer firms, accounting, revenue, establishments, services, and USA.',
    'urls': [
        'https://fred.stlouisfed.org/series/REVEF71391ALLEST'
    ]
})

coll.insert_one({
    'topic': 'Golf',
    'title': 'Total Revenue for Golf Courses and Country Clubs, All Establishments, Employer Firms',
    'license': 'N/A',
    'description': 'Graph and download economic data for Total Revenue for Golf Courses and Country Clubs, All Establishments, Employer Firms (REVEF71391ALLEST) from 1998 to 2017 about sport, recreation, employer firms, accounting, revenue, establishments, services, and USA.',
    'urls': [
        'https://fred.stlouisfed.org/series/REVEF71391ALLEST'
    ]
})

coll.insert_one({
    'topic': 'Basketball',
    'title': 'NCAA Basketball: Data back to 1894',
    'license': 'CC0: Public Domain',
    'description': 'This dataset contains data about NCAA Basketball games, teams, and players. Game data covers play-by-play and box scores back to 2009, as well as final scores back to 1996. Additional data about wins and losses goes back to the 1894-5 season in some teams\' cases.',
    'urls': [
        'https://www.kaggle.com/ncaa/ncaa-basketball'
    ]
})

coll.insert_one({
    'topic': 'Basketball',
    'title': 'Basketball Equipment Industry Overview',
    'license': 'N/A',
    'description': 'Basketball Equipment performance statistics including transactions, price, conversion rate and top product categories.',
    'urls': [
        'https://www.jumpshot.com/category/sports-fitness-outdoors/basketball'
    ]
})

#####

coll.insert_one({
    'topic': 'Basketball',
    'title': 'USA BASKETBALL, fiscal year ending Sept. 2016',
    'license': 'N/A',
    'description': 'ProPublica\'s Nonprofit Explorer lets you view summaries of 2.2 million tax returns from tax-exempt organizations and see financial details such as their executive compensation and revenue and expenses. You can browse raw IRS data released since 2013 and access over 9.4 million tax filing documents going back as far as 2001.',
    'urls': [
        'https://projects.propublica.org/nonprofits/organizations/370996441'
    ]
})

coll.insert_one({
    'topic': 'Basketball',
    'title': 'Fake Basketball Team Stats',
    'license': 'Other',
    'description': 'Included in this data set are the various players on the Basketball team along with their height, dominant playing hand, points per game, and assists per game. It was created in excel using a random number generator.',
    'urls': [
        'https://data.world/chris-helmey/fake-basketball-team-stats'
    ]
})

coll.insert_one({
    'topic': 'Basketball',
    'title': 'Number of participants in U.S. high school basketball 2018/19, by gender',
    'license': 'N/A',
    'description': 'The statistic shows the number of participants (male/female) in high school basketball in the United States from 2009/10 to 2018/19. In the 2018/19 season, just over 541 thousand boys participated in a high school basketball program.',
    'urls': [
        'https://www.statista.com/statistics/267942/participation-in-us-high-school-basketball/'
    ]
})

coll.insert_one({
    'topic': 'Basketball',
    'title': 'Height and lifespan in professional basketball players',
    'license': 'CC4.0',
    'description': 'This dataset examines living and deceased players who have played in the National Basketball Association (debut between 1946 – 2010) and/or the American Basketball Association (1967–1976) using descriptive and Kaplan-Meier and Cox regression analyses. The cut-off date for death data collection was December 11, 2015.',
    'urls': [
        'https://figshare.com/articles/Height_and_lifespan_in_professional_basketball_players/5421958/1'
    ]
})

coll.insert_one({
    'topic': 'Basketball',
    'title': 'National Basketball Association all-time scoring leaders 1946-2019',
    'license': 'N/A',
    'description': 'How many points does LeBron James have? In March 2019, LeBron James passed Michael Jordan on the NBA all-time scoring list, scoring his 32,293rd point in a regular season game against the Denver Nuggets. James currently ranks fourth on the list and If he continues to produce at about his career average, he will pass Kobe Bryant at some point during the 2019/20 season for third place on the list. He has a shot to move up even further and pass Karl Malone with about two more full seasons of games, and even catch Kareem Abdul-Jabbar, the NBA’s current all-time leading scorer, while on his current contract with the Los Angeles Lakers which runs through the 2021/22 season.',
    'urls': [
        'https://www.statista.com/statistics/271305/all-time-nba-scoring-leaders/'
    ]
})

#####

coll.insert_one({
    'topic': 'Basketball',
    'title': 'NCAA men\'s college basketball championships by team 1939-2019',
    'license': 'N/A',
    'description': 'The statistic shows the men\'s college basketball teams with the most NCAA Division I championships from 1939 to 2019.',
    'urls': [
        'https://www.statista.com/statistics/219821/teams-with-the-most-ncaa-basketball-titles/'
    ]
})

coll.insert_one({
    'topic': 'Basketball',
    'title': 'NCAA men\'s basketball final four appearances by team 1999-2019',
    'license': 'N/A',
    'description': 'The statistic shows the men\'s college basketball teams with the most NCAA Division I final four appearances from 1939 to 2019. UCLA was amongst the best four college basketball teams a total of 17 times.',
    'urls': [
        'https://www.statista.com/statistics/219824/teams-with-the-most-ncaa-mens-basketball-final-four-appearances/'
    ]
})

coll.insert_one({
    'topic': 'Basketball',
    'title': 'NCAA division I men\'s basketball attendance leaders 2019',
    'license': 'N/A',
    'description': 'While the players on the court might still be college students, the National Collegiate Athletic Association men\'s basketball top division still draws in big crowds. The Syracuse Orange men\'s basketball, which represents Syracuse University in New York, attracted the highest average attendance during the 2019 season. The team, traditionally known as the Syracuse Orangemen, had an average home audience of almost 22 thousand in 2019.',
    'urls': [
        'https://www.statista.com/statistics/219827/attendance-at-ncaa-mens-basketball-games/'
    ]
})

coll.insert_one({
    'topic': 'Basketball',
    'title': 'National Basketball Association all-time triple double leaders 1946-2019',
    'license': 'N/A',
    'description': 'Which player has the most triple doubles? Oscar Robertson - nicknamed ‘The Big O’, is the all-time leader in triple doubles in the National Basketball Assocation. He compiled 181 triple doubles during his playing career with the Cincinnati Royals and the Milwaukee Bucks (1960 to 1974). The highest ranked active player is Russell Westbrook of the Oklahoma City Thunder with 138 triple doubles, tied with Earvin \'Magic\’ Johson for second place.',
    'urls': [
        'https://www.statista.com/statistics/695594/all-time-nba-triple-double-leaders/'
    ]
})

coll.insert_one({
    'topic': 'Basketball',
    'title': 'National Basketball Association (NBA) Dataset',
    'license': 'CC0: Public Domain',
    'description': 'Machine learning dataset to train and test statistics of NBA teams. From their PPG, total wins/losses, APG, BPG, and more, the dataset contains all statistics of a team in the year of playing.',
    'urls': [
        'https://www.kaggle.com/amanajmera1/national-basketball-associationnba-dataset'
    ]
})

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['clemon3']
pp = pprint.PrettyPrinter(indent=1,width=65)
count = 0
for r in coll. find():
    print(pp.pformat (r))
    count += 1

print(count)
# Out:
# {'_id': ObjectId('5d88d496ca4c081382790b2d'),
#  'description': 'The datasets consist of all the statistics of '
#                 'all of the players on the PGA Tour from 2010 - '
#                 'August 25, 2019. The data will be updated '
#                 'weekly at the conclusion of each tournament. '
#                 'The most recent tournament in the 2019 data '
#                 'set is The Tour Championship.',
#  'license': 'CC BY-NC-SA 4.0',
#  'title': 'PGA Tour Golf Data',
#  'topic': 'Golf',
#  'urls': ['https://www.kaggle.com/bradklassen/pga-tour-20102018-data']}
# {'_id': ObjectId('5d88d971ca4c081382790b30'),
#  'description': 'The datasets consist of all the statistics of '
#                 'all of the players on the PGA Tour from 2010 - '
#                 'August 25, 2019. The data will be updated '
#                 'weekly at the conclusion of each tournament. '
#                 'The most recent tournament in the 2019 data '
# ...
