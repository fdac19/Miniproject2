# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['cwilder8']
# for each dataset
coll.insert_one({'topic':'sale/rating URLs', 'first dataset': 'video game sales with ratings', 'license': 'NA', 'description': 'Video game sales data compared to ratings', 'urls': 
                 [ 'https://www.kaggle.com/rush4ratio/video-game-sales-with-ratings', 'https://www.kaggle.com/kendallgillies/video-game-sales-and-ratings']})

coll.insert_one({'topic':'sale URLs','second dataset': 'video game sales', 'license': 'NA', 'description': 'Top video games ordered by sales data', 'urls': 
                 [ 'https://www.kaggle.com/ashaheedq/video-games-sales-2019', 'https://www.statista.com/statistics/273258/us-computer-and-video-game-sales/', 
                 'https://www.statista.com/statistics/263258/computer-games-unit-sales-in-the-us/', 'https://www.statista.com/statistics/190225/digital-and-physical-game-sales-in-the-us-since-2009/', 
                 'https://www.statista.com/statistics/190184/us-computer-and-video-game-sales-by-categorie-2010/', 'https://www.statista.com/statistics/273335/sales-of-the-worlds-most-popular-console-games-in-2011/', 
                 'https://data.world/julienf/video-games-global-sales-in-volume-1983-2017', 'https://www.statista.com/statistics/784803/australia-video-game-sales/',
                 'https://www.statista.com/statistics/499390/leading-pc-steam-games-by-unit-sales/', 'https://www.statista.com/statistics/321374/global-all-time-unit-sales-call-of-duty-games/',
                 'https://www.statista.com/statistics/381022/best-selling-video-games-germany/', 'https://www.statista.com/statistics/566588/video-games-sales-value-distribution-by-pegi-rating-system-in-italy/',
                 'https://www.statista.com/statistics/274072/most-popular-games-in-the-united-kingdom-uk-by-unit-sales/', 'https://www.statista.com/statistics/516598/best-selling-video-game-ps4-global-unit-sales/',
                 'https://www.statista.com/statistics/453141/best-selling-console-games-in-europe/', 'https://www.statista.com/statistics/500608/best-selling-video-games-japan-unit-sales/',
                 'https://www.statista.com/statistics/380139/best-selling-video-games-in-france/', 'https://www.statista.com/statistics/516581/best-selling-video-game-xbox-one-global-unit-sales/']})

coll.insert_one({'topic':'game ranking URLs','second dataset': 'video game rankings', 'license': 'NA', 'description': 'Top video games ordered by ranking', 'urls':
                 [ 'https://www.kaggle.com/skateddu/metacritic-games-stats-20112019', 'https://data.world/craigkelly/steam-game-data',
                  'https://static1.statista.com/statistics/1040814/russia-video-game-usage-by-device-and-age/', 'https://static1.statista.com/statistics/189592/breakdown-of-us-video-game-sales-2009-by-genre/',
                  'https://static1.statista.com/statistics/499025/most-anticipated-pc-video-game-titles/', 'https://static2.statista.com/statistics/321059/game-engines-used-by-video-game-developers-uk/',
                  'https://cdn.statista.com/statistics/629131/favorite-video-game-wii-u-italy/', 'https://static1.statista.com/statistics/593779/favorite-video-game-genre-italy/']})

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['cwilder8']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp.pformat (r))
# Out:
# {'_id': ObjectId('5d88285fe298147e6f55490a'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
#  'urls': ['https://www.kaggle.com/tamber/steam-video-games']}
# {'_id': ObjectId('5d882945e298147e6f55490f'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
#  'urls': ['https://www.kaggle.com/tamber/steam-video-games']}
# {'_id': ObjectId('5d882961e298147e6f554914'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
#  'urls': ['https://www.kaggle.com/tamber/steam-video-games']}
# {'_id': ObjectId('5d882c7fe298147e6f554917'),
# ...
