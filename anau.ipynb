# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['anau']
# for each dataset
coll.insert_one ( { 'topic':'health', 'title': 'largest projects', 'license': 'NA', 'description': 'The list of projects on github with the largest number of starts', 'urls': [ 'url1', 'url2' ] } )
coll.insert_one ( { 'topic':'health', 'title': 'Arrhythmia', 'license': 'NA', 'description': 'Data set used for classification. Distinguish between the presence and absence of cardiac arrhythmia and classify it in one of the 16 groups.', 'urls': [ 'http://mlr.cs.umass.edu/ml/datasets/Arrhythmia'] } )
coll.insert_one ( { 'topic':'health', 'title': 'Breast Cancer Wisconsin ', 'license': 'NA', 'description': 'Each record represents follow-up data for one breast cancer case. These are consecutive patients seen by Dr. Wolberg since 1984, and include only those cases exhibiting invasive breast cancer and no evidence of distant metastases at the time of diagnosis.', 'urls': [ 'http://mlr.cs.umass.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Prognostic%29'] } )
coll.insert_one ( { 'topic':'health', 'title': 'Audiology (Original) Data Set', 'license': 'NA', 'description': 'Nominal audiology dataset from Baylor', 'urls': [ 'http://mlr.cs.umass.edu/ml/datasets/Audiology+%28Original%29' ] } )
coll.insert_one ( { 'topic':'health', 'title': 'Audiology (Standardized) Data Set', 'license': 'NA', 'description': 'Standardized version of the original audiology database', 'urls': [ 'http://mlr.cs.umass.edu/ml/datasets/Audiology+%28Standardized%29' ] } )
coll.insert_one ( { 'topic':'health', 'title': 'Breast Cancer Data Set ', 'license': 'NA', 'description': 'This is one of three domains provided by the Oncology Institute that has repeatedly appeared in the machine learning literature. (See also lymphography and primary-tumor.) This data set includes 201 instances of one class and 85 instances of another class. The instances are described by 9 attributes, some of which are linear and some are nominal. ', 'urls': [ 'http://mlr.cs.umass.edu/ml/datasets/Breast+Cancer' ] } )
coll.insert_one ( { 'topic':'health', 'title': 'Heart Disease Mortality Data Among US Adults (35+) by State/Territory and County – 2015-2017', 'license': 'NA', 'description': '2015 to 2017, 3-year average. Rates are age-standardized. County rates are spatially smoothed. The data can be viewed by gender and race/ethnicity. Data source: National Vital Statistics System. Additional data, maps, and methodology can be viewed on the Interactive Atlas of Heart Disease and Stroke', 'urls': [ 'https://healthdata.gov/dataset/heart-disease-mortality-data-among-us-adults-35-stateterritory-and-county-–-2015-2017' ] } )
coll.insert_one ( { 'topic':'health', 'title': 'Pit Stop Locations', 'license': 'NA', 'description': "San Francisco Public Works operates the Pit Stop program, which provides clean and safe public toilets, sinks, used needle receptacles and dog waste stations in San Francisco's most impacted neighborhoods", 'urls': [ 'https://healthdata.gov/dataset/pit-stop-locations' ] } )
coll.insert_one ( { 'topic':'health', 'title': 'Stroke Mortality Data Among US Adults (35+)', 'license': 'NA', 'description': '2015 to 2017, 3-year average. Rates are age-standardized. County rates are spatially smoothed. The data can be viewed by gender and race/ethnicity. Data source: National Vital Statistics System. Additional data, maps, and methodology can be viewed on the Interactive Atlas of Heart Disease and Stroke.', 'urls': [ 'https://healthdata.gov/dataset/stroke-mortality-data-among-us-adults-35-stateterritory-and-county-–-2015-2017' ] } )
coll.insert_one ( { 'topic':'health', 'title': 'Chemical Effects in Biological Systems (CEBS)', 'license': 'NA', 'description': 'The Chemical Effects in Biological Systems database (CEBS: https://manticore.niehs.nih.gov/cebssearch/) houses data from the National Toxicology Program research and testing program. CEBS data from individual animals is here, organized into data domains. CEBS data are also available for search.', 'urls': [ 'https://healthdata.gov/dataset/chemical-effects-biological-systems-cebs' ] } )

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['anau']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d86e90f28b7b61598f33ffe'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
#  'urls': ['url1', 'url2']}
# {'_id': ObjectId('5d86e90f28b7b61598f33fff'),
#  'description': 'Distinguish between the presence and absence '
#                 'of cardiac arrhythmia and classify it in one '
#                 'of the 16 groups.',
#  'license': 'NA',
#  'title': 'Arrhythmia',
#  'topic': 'health',
#  'urls': ['http://mlr.cs.umass.edu/ml/datasets/Arrhythmia']}
# {'_id': ObjectId('5d86eee628b7b6182d845abc'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'license': 'NA',
#  'title': 'largest projects',
#  'topic': 'health',
#  'urls': ['url1', 'url2']}
# {'_id': ObjectId('5d86eee628b7b6182d845abd'),
#  'description': 'Data set used for classification. Distinguish '
# ...

# %%
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   """Entry point for launching an IPython kernel.
# 31
