# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['anau']
# for each dataset
#coll.insert_one ( { 'topic':'health', 'title': 'Arrhythmia', 'license': 'NA', 'description': 'Data set used for classification. Distinguish between the presence and absence of cardiac arrhythmia and classify it in one of the 16 groups.', 'urls': [ 'http://mlr.cs.umass.edu/ml/datasets/Arrhythmia'] } )
#coll.insert_one ( { 'topic':'health', 'title': 'Breast Cancer Wisconsin ', 'license': 'NA', 'description': 'Each record represents follow-up data for one breast cancer case. These are consecutive patients seen by Dr. Wolberg since 1984, and include only those cases exhibiting invasive breast cancer and no evidence of distant metastases at the time of diagnosis.', 'urls': [ 'http://mlr.cs.umass.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Prognostic%29'] } )
#coll.insert_one ( { 'topic':'health', 'title': 'Audiology (Original) Data Set', 'license': 'NA', 'description': 'Nominal audiology dataset from Baylor', 'urls': [ 'http://mlr.cs.umass.edu/ml/datasets/Audiology+%28Original%29' ] } )
#coll.insert_one ( { 'topic':'health', 'title': 'Audiology (Standardized) Data Set', 'license': 'NA', 'description': 'Standardized version of the original audiology database', 'urls': [ 'http://mlr.cs.umass.edu/ml/datasets/Audiology+%28Standardized%29' ] } )
#coll.insert_one ( { 'topic':'health', 'title': 'Breast Cancer Data Set ', 'license': 'NA', 'description': 'This is one of three domains provided by the Oncology Institute that has repeatedly appeared in the machine learning literature. (See also lymphography and primary-tumor.) This data set includes 201 instances of one class and 85 instances of another class. The instances are described by 9 attributes, some of which are linear and some are nominal. ', 'urls': [ 'http://mlr.cs.umass.edu/ml/datasets/Breast+Cancer' ] } )
#coll.insert_one ( { 'topic':'health', 'title': 'Heart Disease Mortality Data Among US Adults (35+) by State/Territory and County – 2015-2017', 'license': 'Open Data Commons Open Database License (ODbL)', 'description': '2015 to 2017, 3-year average. Rates are age-standardized. County rates are spatially smoothed. The data can be viewed by gender and race/ethnicity. Data source: National Vital Statistics System. Additional data, maps, and methodology can be viewed on the Interactive Atlas of Heart Disease and Stroke', 'urls': [ 'https://healthdata.gov/dataset/heart-disease-mortality-data-among-us-adults-35-stateterritory-and-county-–-2015-2017' ] } )
#coll.insert_one ( { 'topic':'health', 'title': 'Pit Stop Locations', 'license': 'Open Data Commons Open Database License (ODbL)', 'description': "San Francisco Public Works operates the Pit Stop program, which provides clean and safe public toilets, sinks, used needle receptacles and dog waste stations in San Francisco's most impacted neighborhoods", 'urls': [ 'https://healthdata.gov/dataset/pit-stop-locations' ] } )
#coll.insert_one ( { 'topic':'health', 'title': 'Stroke Mortality Data Among US Adults (35+)', 'license': 'Open Data Commons Open Database License (ODbL)', 'description': '2015 to 2017, 3-year average. Rates are age-standardized. County rates are spatially smoothed. The data can be viewed by gender and race/ethnicity. Data source: National Vital Statistics System. Additional data, maps, and methodology can be viewed on the Interactive Atlas of Heart Disease and Stroke.', 'urls': [ 'https://healthdata.gov/dataset/stroke-mortality-data-among-us-adults-35-stateterritory-and-county-–-2015-2017' ] } )
#coll.insert_one ( { 'topic':'health', 'title': 'Chemical Effects in Biological Systems (CEBS)', 'license': 'Open Data Commons Open Database License (ODbL)', 'description': 'The Chemical Effects in Biological Systems database (CEBS: https://manticore.niehs.nih.gov/cebssearch/) houses data from the National Toxicology Program research and testing program. CEBS data from individual animals is here, organized into data domains. CEBS data are also available for search.', 'urls': [ 'https://healthdata.gov/dataset/chemical-effects-biological-systems-cebs' ] } )
#coll.insert_one ( { 'topic':'health', 'title': 'Sequence Read Archive (SRA)', 'license': 'Open Data Commons Open Database License (ODbL)', 'description': 'The Sequence Read Archive (SRA) stores raw sequencing data from the next generation of sequencing platforms', 'urls': [ 'https://healthdata.gov/dataset/sequence-read-archive-sra' ] } )
#coll.insert_one ( { 'topic':'health', 'title': 'Adult Binge Drinking', 'license': 'NA', 'description': 'Percent of adults who binge drink', 'urls': [ 'https://bchi.bigcitieshealth.org/indicators/1827/searches/34446' ] } )
#coll.insert_one ( { 'topic':'health', 'title': 'Motor Vehicle Mortality Rate', 'license': 'NA', 'description': 'Data set about motor vehicle rate', 'urls': [ 'https://bchi.bigcitieshealth.org/indicators/1872/searches/34543' ] } )
#coll.insert_one ( { 'topic':'health', 'title': 'Lung Cancer Mortality Rate', 'license': 'NA', 'description': 'Data set about lung cancer mortailty rate', 'urls': [ 'https://bchi.bigcitieshealth.org/indicators/1831/searches/34451' ] } )
#coll.insert_one ( { 'topic':'health', 'title': 'Health Facility Certification Information', 'license': 'Open Database License (ODbL)', 'description': 'This dataset contains information on certifications for services and beds for Article 28, Article 36, and Article 40 health care facilities, and programs from the Health Facilities Information System (HFIS).', 'urls': [ 'https://healthdata.gov/dataset/health-facility-certification-information' ] } )
#coll.insert_one ( { 'topic':'health', 'title': 'Washington Health Workforce Survey Data', 'license': 'Open Database License (ODbL)', 'description': "The Washington State Department of Health presents this information as a service to the public. This includes information on the work status, practice characteristics, education, and demographics of healthcare providers, provided in response to the Washington Health Workforce Survey. This is a complete set of data across all of the responding professions. The data dictionary identifies questions that are specific to an individual profession and aren't common to all surveys. The dataset is provided without identifying information for the responding providers.", 'urls': [ 'https://healthdata.gov/dataset/washington-health-workforce-survey-data' ] } )
#coll.insert_one ( { 'topic':'health', 'title': 'Office of Medicare Hearings and Appeals', 'license': 'Open Database License (ODbL)', 'description': 'This data set provides information about the appeals and claims received by the Office of Medicare and Hearings by state for Fiscal Year 2006 - 2012.', 'urls': [ 'https://healthdata.gov/dataset/office-medicare-hearings-and-appeals-omha-receipts-state' ] } )
#coll.insert_one ( { 'topic':'health', 'title': 'Prevalence and Mean of Dental Caries among Maryland School Children', 'license': 'Open Database License (ODbL)', 'description': 'This is the weighted prevalence of 1,276 schoolchildren. 1,276 out of 1,280 cases examined had prevalence available. One out of 1,276 cases had grade information missed, 564 were in Kindergarten and 711 in 3rd grade. Prevalence is defined as occurrence of any caries among all selected population. Mean is the average number of teeth with caries among students with caries in the selected population.', 'urls': [ 'https://healthdata.gov/dataset/prevalence-and-mean-dental-caries-among-maryland-school-children-2005-2006' ] } )
#coll.insert_one ( { 'topic':'health', 'title': 'Child Support Enforcement Annual Data Report', 'license': 'Open Database License (ODbL)', 'description': 'State officials use the OCSE-157 to report annual statistical and financial information on their Child Support Enforcement (CSE) program to the Department of Health and Human Services (HHS). This information will enable the Secretary of HHS to comply with sections 409, 452(a) and (g), 458, and 469 of the Social Security Act (the Act). The Act requires the Secretary to establish standards for an effective Child Support Enforcement program, and to make an Annual Report to the Congress on program activities.', 'urls': [ 'https://healthdata.gov/dataset/prevalence-and-mean-dental-caries-among-maryland-school-children-2005-2006' ] } )
#coll.insert_one ( { 'topic':'health', 'title': 'National Survey on Drug Use and Health (NSDUH), 2009', 'license': 'Open Database License (ODbL)', 'description': 'The National Survey on Drug Use and Health (NSDUH) series (formerly titled National Household Survey on Drug Abuse) primarily measures the prevalence and correlates of drug use in the United States.', 'urls': [ 'https://healthdata.gov/dataset/national-survey-drug-use-and-health-nsduh-2009' ] } )
#coll.insert_one ( { 'topic':'health', 'title': 'Risk-Adjusted Inpatient Mortality Rates and Hospital Ratings for California Hospitals', 'license': 'Open Database License (ODbL)', 'description': 'The dataset contains risk-adjusted mortality rates, quality ratings, and number of deaths and cases for 6 medical conditions treated (Acute Stroke, Acute Myocardial Infarction, Heart Failure, Gastrointestinal Hemorrhage, Hip Fracture and Pneumonia) and 6 procedures performed (Abdominal Aortic Aneurysm Repair, Carotid Endarterectomy, Craniotomy, Esophageal Resection, Pancreatic Resection, Percutaneous Coronary Intervention) in California hospitals for 2012. This dataset does not include conditions treated or procedures performed in outpatient settings.', 'urls': [ 'https://healthdata.gov/dataset/risk-adjusted-inpatient-mortality-rates-and-hospital-ratings-california-hospitals-2012-3' ] } )

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['anau']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d87ba3328b7b65722209953'),
#  'description': 'Data set used for classification. Distinguish '
#                 'between the presence and absence of cardiac '
#                 'arrhythmia and classify it in one of the 16 '
#                 'groups.',
#  'license': 'NA',
#  'title': 'Arrhythmia',
#  'topic': 'health',
#  'urls': ['http://mlr.cs.umass.edu/ml/datasets/Arrhythmia']}
# {'_id': ObjectId('5d87ba4228b7b65722209955'),
#  'description': 'Each record represents follow-up data for one '
#                 'breast cancer case. These are consecutive '
#                 'patients seen by Dr. Wolberg since 1984, and '
#                 'include only those cases exhibiting invasive '
#                 'breast cancer and no evidence of distant '
#                 'metastases at the time of diagnosis.',
#  'license': 'NA',
#  'title': 'Breast Cancer Wisconsin ',
#  'topic': 'health',
# ...

# %%
# number of documents in collection
coll.count()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
# 20
