# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['tkeyes1']
# for each dataset
# coll.remove({}) for restarting

coll.insert_one ( { 'topic':'Networks', 'title': 'YouTube Video Social Graph', 'license': 'Unknown', 'description': 'Crawl for related YouTube videos', 'urls': [ 'http://netsg.cs.sfu.ca/youtubedata/' ] } )
coll.insert_one ( { 'topic':'Networks', 'title': 'Reddit Comments', 'license': 'Unknown', 'description': 'Dataset of Reddit comments', 'urls': [ 'http://files.pushshift.io/reddit/comments/' ] } )
coll.insert_one ( { 'topic':'Networks', 'title': 'Social Twitter Data', 'license': 'Unknown', 'description': 'Some graph theaory on Twitter data', 'urls': [ 'http://snap.stanford.edu/data/egonets-Twitter.html' ] } )
coll.insert_one ( { 'topic':'Networks', 'title': 'GitHub Collaboration Archive', 'license': 'Unknown', 'description': 'Communication data via GitHub', 'urls': [ 'https://www.gharchive.org/' ] } )
coll.insert_one ( { 'topic':'Networks', 'title': 'SkyTrax Reviews', 'license': 'Unknown', 'description': 'SkyTrax Airline reviews data', 'urls': [ 'https://github.com/quankiquanki/skytrax-reviews-dataset' ] } )
coll.insert_one ( { 'topic':'Networks', 'title': 'Yahoo Graph and Social Data', 'license': 'Unknown', 'description': 'Yahoo Graph and Social Data (various)', 'urls': [ 'https://webscope.sandbox.yahoo.com/catalog.php?datatype=g&guccounter=1' ] } )
coll.insert_one ( { 'topic':'Networks', 'title': 'Facebook Data Scrape', 'license': 'Unknown', 'description': '100 College and Universities and data for friendships within colleges', 'urls': [ 'https://archive.org/details/oxford-2005-facebook-matrix' ] } )
coll.insert_one ( { 'topic':'Networks', 'title': 'Twitter Network Dataset', 'license': 'Unknown', 'description': 'Networks differing from re-tweeting, replying, mentioning, etc.', 'urls': [ 'http://snap.stanford.edu/data/higgs-twitter.html' ] } )
coll.insert_one ( { 'topic':'Networks', 'title': 'US Congress Twitter Datasets', 'license': 'Unknown', 'description': 'Datasets of the daily output of Congress', 'urls': [ 'https://github.com/alexlitel/congresstweets' ] } )
coll.insert_one ( { 'topic':'Networks', 'title': 'Ancestry.com Forum Dataset', 'license': 'Unknown', 'description': 'Various data for social network analysis', 'urls': [ 'http://www.cs.cmu.edu/~jelsas/data/ancestry.com/' ] } )
coll.insert_one ( { 'topic':'Networks', 'title': 'Google+ Social Circles', 'license': 'Unknown', 'description': 'From users who enabled “Shared Circle” feature', 'urls': [ 'https://snap.stanford.edu/data/ego-Gplus.html' ] } )
coll.insert_one ( { 'topic':'Networks', 'title': 'Twitter Social Circles', 'license': 'Unknown', 'description': 'Circles from Twitter', 'urls': [ 'https://snap.stanford.edu/data/ego-Twitter.html' ] } )
coll.insert_one ( { 'topic':'Networks', 'title': 'Facebook Social Circles', 'license': 'Unknown', 'description': 'Circles from Facebook', 'urls': [ 'https://snap.stanford.edu/data/ego-Facebook.html' ] } )
coll.insert_one ( { 'topic':'Networks', 'title': 'LiveJournal Social Network', 'license': 'Unknown', 'description': 'Open data from users of LiveJournal', 'urls': [ 'https://snap.stanford.edu/data/soc-LiveJournal1.html' ] } )
coll.insert_one ( { 'topic':'Networks', 'title': 'Hollywood film music', 'license': 'Unknown', 'description': 'Collaboration of 40 composers and 62 producers with minimum of 5 movies', 'urls': [ 'http://networkdata.ics.uci.edu/netdata/html/movies.html' ] } )
coll.insert_one ( { 'topic':'Networks', 'title': 'Bernard and Killworth Fraternity', 'license': 'Unknown', 'description': 'Interactions between students at a West Virginia fraternity', 'urls': [ 'http://networkdata.ics.uci.edu/netdata/html/bkFrat.html' ] } )
coll.insert_one ( { 'topic':'Networks', 'title': 'Actor Movies', 'license': 'Unknown', 'description': 'Bipartite network of movies and the actors that played in them', 'urls': [ 'http://konect.uni-koblenz.de/networks/actor-movie' ] } )
coll.insert_one ( { 'topic':'Networks', 'title': 'Wikipedia Requests for Adminship', 'license': 'Unknown', 'description': 'RFA submissions from users', 'urls': [ 'http://snap.stanford.edu/data/wiki-RfA.html' ] } )
coll.insert_one ( { 'topic':'Networks', 'title': 'SourceForge.net Research Data', 'license': 'Unknown', 'description': 'Project and research data from over 140,000 projects', 'urls': [ 'https://www3.nd.edu/~oss/Data/data.html' ] } )
coll.insert_one ( { 'topic':'Networks', 'title': 'Google Scholar Citation Relations', 'license': 'Unknown', 'description': 'Dataset of Google Scholar Citations and their relations', 'urls': [ 'http://www3.cs.stonybrook.edu/~leman/data/gscholar.db' ] } )

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['tkeyes1']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d84200580942816ed8c43aa'),
#  'description': 'Crawl for related YouTube videos',
#  'license': 'Unknown',
#  'title': 'YouTube Video Social Graph',
#  'topic': 'Networks',
#  'urls': ['http://netsg.cs.sfu.ca/youtubedata/']}
# {'_id': ObjectId('5d84200580942816ed8c43ab'),
#  'description': 'Dataset of Reddit comments',
#  'license': 'Unknown',
#  'title': 'Reddit Comments',
#  'topic': 'Networks',
#  'urls': ['http://files.pushshift.io/reddit/comments/']}
# {'_id': ObjectId('5d84200580942816ed8c43ac'),
#  'description': 'Some graph theaory on Twitter data',
#  'license': 'Unknown',
#  'title': 'Social Twitter Data',
#  'topic': 'Networks',
#  'urls': ['http://snap.stanford.edu/data/egonets-Twitter.html']}
# {'_id': ObjectId('5d84200580942816ed8c43ad'),
#  'description': 'Communication data via GitHub',
#  'license': 'Unknown',
#  'title': 'GitHub Collaboration Archive',
#  'topic': 'Networks',
#  'urls': ['https://www.gharchive.org/']}
# ...
