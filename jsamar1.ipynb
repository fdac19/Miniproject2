# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['jsamar1']
# for each dataset
coll.insert_one ( { 'topic': 'Traffic Patterns', 'title':'Traffic Stops', 'license': 'Public Domain', 'description': 'Information related to traffic stops by officers in Saint Paul', 'urls': [ 'https://information.stpaul.gov/Public-Safety/Traffic-Stop-Dataset/kkd6-vvns' ] } )
coll.insert_one ( { 'topic': 'Traffic Patterns', 'title':'Data From Traffic Counters', 'license': 'Creative Commons Attribution', 'description': 'Pedestrian, biking, traffic, and crash data from counters', 'urls': [ 'https://catalog.data.gov/dataset/234fd9d4-fb56-48de-8798-db6f854e203c' ] } )
coll.insert_one ( { 'topic': 'Traffic Patterns', 'title':'Austin, TX Traffic Cameras', 'license': 'Public Domain', 'description': 'Info on every traffic camera in use and screenshots each 5 minutes from some', 'urls': [ 'https://data.austintexas.gov/Transportation-and-Mobility/Traffic-Cameras/b4k4-adkb' ] } )
coll.insert_one ( { 'topic': 'Traffic Patterns', 'title':'US Traffic Fatality Records', 'license': 'Public Domain', 'description': 'Every traffic crash on a public road that has resulted in a death within 30 days', 'urls': [ 'https://www.kaggle.com/usdot/nhtsa-traffic-fatalities' ] } )
coll.insert_one ( { 'topic': 'Traffic Patterns', 'title':'UK Journey Time data', 'license': 'Open Government Licence', 'description': 'Journey time of vehicles using real vehicle observatios', 'urls': [ 'http://tris.highwaysengland.co.uk/detail/journeytimedata' ] } )
coll.insert_one ( { 'topic': 'Traffic Patterns', 'title':'UK Traffic Flow', 'license': 'Open Government Licence', 'description': '15 minute time slot of traffic flow', 'urls': [ 'http://tris.highwaysengland.co.uk/detail/trafficflowdata' ] } )
coll.insert_one ( { 'topic': 'Traffic Patterns', 'title':'Buffalo Traffic Data', 'license': 'Government Works', 'description': 'Traffic volume calculations for areas in the city of Buffalo, NY', 'urls': [ 'https://data.buffalony.gov/Transportation/Annual-Average-Daily-Traffic-Volume-Counts/y93c-u65y' ] } )
coll.insert_one ( { 'topic': 'Traffic Patterns', 'title':'NY Traffic Volume Counts', 'license': 'Public Domain', 'description': 'Traffic volume on particular streets at certain times', 'urls': [ 'https://data.cityofnewyork.us/Transportation/Traffic-Volume-Counts-2014-2018-/ertz-hr4r' ] } )
coll.insert_one ( { 'topic': 'Traffic Patterns', 'title':'Lethbridge Traffic Counts',  'license': 'Custom Open Data License', 'description': 'Traffic volume on the city of Lethbridge, AB', 'urls': [ 'http://opendata.lethbridge.ca/datasets/d37288dfd70d48ac9b4426ed68008ba2_0/data' ] } )
coll.insert_one ( { 'topic': 'Traffic Patterns', 'title':'Los Angeles Traffic Counts',  'license': 'N/A', 'description': 'Traffic flow data on various areas within Los Angeles', 'urls': [ 'http://geohub.lacity.org/datasets/traffic-data/data' ] } )
coll.insert_one ( { 'topic': 'Traffic Patterns', 'title':'Rhode Island Traffic Counts', 'license': 'Custom License', 'description': 'Traffic count data on state roads in Rhode Island', 'urls': [ 'http://www.rigis.org/datasets/f1960095a25b471abd172a88e154f885_0' ] } )
coll.insert_one ( { 'topic': 'Traffic Patterns', 'title':'Cambridgeshire Collisions',  'license': 'Open Government Licence', 'description': 'Traffic collisions across Cambridgeshire', 'urls': [ 'https://data.gov.uk/dataset/b6228583-a7d6-4318-b692-54c079e020ca/road-traffic-collisions-location' ] } )
coll.insert_one ( { 'topic': 'Traffic Patterns', 'title':'Austin Radar Traffic Counts', 'license': 'Public Domain', 'description': 'Traffic counts and speed data collected by Austin, TX', 'urls': [ 'https://data.austintexas.gov/Transportation-and-Mobility/Radar-Traffic-Counts/i626-g7ub' ] } )
coll.insert_one ( { 'topic': 'Traffic Patterns', 'title':'Los Angeles Traffic Collisions',  'license': 'Public Domain', 'description': 'Traffic collision data from 2010 to present in Los Angeles', 'urls': [ 'https://data.lacity.org/A-Safe-City/Traffic-Collision-Data-from-2010-to-Present/d5tf-ez2w' ] } )
coll.insert_one ( { 'topic': 'Traffic Patterns', 'title':'Chicago Congestion',  'license': 'Public Domain', 'description': 'Estimated congestion for traffic segments', 'urls': [ 'https://data.cityofchicago.org/Transportation/Chicago-Traffic-Tracker-Historical-Congestion-Esti/77hq-huss' ] } )
coll.insert_one ( { 'topic': 'Traffic Patterns', 'title':'Maryland Traffic Counts', 'license': 'Custom License', 'description': 'Maryland Traffic counts and various calculations of public roadways', 'urls': [ 'https://hub.arcgis.com/datasets/3f4b959826c34480be3e4740e4ee025f_1' ] } )
coll.insert_one ( { 'topic': 'Traffic Patterns', 'title':'Allegheny Traffic Counts', 'license': 'Creative Commons', 'description': 'Traffic counts from 2012-2014 for Allegheny County, PA', 'urls': [ 'https://data.wprdc.org/dataset/allegheny-county-traffic-counts' ] } )
coll.insert_one ( { 'topic': 'Traffic Patterns', 'title':'Texas AADT Annuals', 'license': 'Custom License', 'description': 'AADT calculations for state roads in TX', 'urls': [ 'http://gis-txdot.opendata.arcgis.com/datasets/txdot-aadt-annuals' ] } )
coll.insert_one ( { 'topic': 'Traffic Patterns', 'title':'Edmonton Traffic Counts', 'license': 'Public Domain', 'description': 'Edmonton traffic counts 2009-2015', 'urls': [ 'https://data.edmonton.ca/Transportation/Average-Annual-Weekday-Traffic-Volumes-2009-2015-/b58q-nxjr' ] } )
coll.insert_one ( { 'topic': 'Traffic Patterns', 'title':'Florida Traffic Counts', 'license': 'Custom License', 'description': 'Florida traffic counts', 'urls': [ 'https://gis-fdot.opendata.arcgis.com/datasets/annual-average-daily-traffic-tda' ] } )

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['jsamar1']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d7e6769e1eaff62f15de0d2'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
#  'urls': ['url1', 'url2']}
# {'_id': ObjectId('5d7edc7c995d246453e1025b'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
#  'urls': ['url1', 'url2']}
# {'_id': ObjectId('5d81827493569c62818e7979'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
#  'urls': ['url1', 'url2']}
# {'_id': ObjectId('5d8193ebd4732fb4def4810e'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
# ...
