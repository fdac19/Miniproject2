# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['smaniko1']
# for each dataset
coll.insert_one ( { 'topic':'Maps', '1st dataset': 'Geologic map of South Asia (geo8ag)', 'license': 'NA', 'description': 'This data set is the digital geologic layer for the map of South Asia. The data set includes arcs, polgons, polygon labels, and attributes for geology, faults, inferred faults, and rivers. The data set is compiled from numerous UNESCO geologic maps to assist in the assessment of oil and gas for the World Energy Project.', 'urls': [ 'https://catalog.data.gov/dataset/geologic-map-of-south-asia-geo8ag', 'https://data.doi.gov/dataset/geologic-map-of-south-asia-geo8ag' ] } )
coll.insert_one ( { 'topic':'Maps', '2nd dataset': 'A digital geologic map database for the State of Oklahoma (NGMDB)', 'license': 'NA', 'description': 'This record is maintained in the National Geologic Map Database (NGMDB). The NGMDB is a Congressionally mandated national archive of geoscience maps, reports, and stratigraphic information, developed according to standards defined by the cooperators, i.e., the USGS and the Association of American State Geologists (AASG). Included in this system is a comprehensive set of publication citations, stratigraphic nomenclature, downloadable content, unpublished source information, and guidance on standards development. The NGMDB contains information on more than 90,000 maps and related geoscience reports published from the early 1800s to the present day, by more than 630 agencies, universities, associations, and private companies. For more information, please see http://ngmdb.usgs.gov/.', 'urls': [ 'https://catalog.data.gov/dataset/a-digital-geologic-map-database-for-the-state-of-oklahoma-ngmdb'] } )
coll.insert_one ( { 'topic':'Maps', '3rd dataset': 'Data from: The Geologic Map of Arkansas', 'license': 'NA', 'description': 'This geologic map was prepared as a part of a continuing study of digital methods and techniques as applied to complex geologic maps. The digital geologic map was created from the orginal linework used to prepare the published paper Geologic Map of Arkansas. Consequently, this geologic map database can be queried in many ways to produce a variety of geologic maps. The analog source of data was Haley, B.R.; assisted by Glick, E.E., Bush, W.V., Clardy, B.F., Stone, C.G., Woodward, M.B., and Zachry, D.L., 1993, Geologic Map of Arkansas: U.S. Geol. Survey, Special Geologic Map, scale 1:500,000.', 'urls': [ 'https://catalog.data.gov/dataset/the-geologic-map-of-arkansas', 'https://data.doi.gov/dataset/the-geologic-map-of-arkansas' ] } )
coll.insert_one ( { 'topic':'Maps', '4th dataset': 'Geologic Map of the State of Florida (NGMDB)', 'license': 'NA', 'description': 'This record is maintained in the National Geologic Map Database (NGMDB). The NGMDB is a Congressionally mandated national archive of geoscience maps, reports, and stratigraphic information, developed according to standards defined by the cooperators, i.e., the USGS and the Association of American State Geologists (AASG). Included in this system is a comprehensive set of publication citations, stratigraphic nomenclature, downloadable content, unpublished source information, and guidance on standards development. The NGMDB contains information on more than 90,000 maps and related geoscience reports published from the early 1800s to the present day, by more than 630 agencies, universities, associations, and private companies. For more information, please see http://ngmdb.usgs.gov/.', 'urls': [ 'https://catalog.data.gov/dataset/geologic-map-of-the-state-of-florida-ngmdb' ] } )
coll.insert_one ( { 'topic':'Maps', '5th dataset': 'Digital Geologic Map of the Marin Headlands and Point Reyes Areas, California (NPS, GRD, GRI, GOGA, PORE, MUWO, MHPR digital map)', 'license': 'NA', 'description': 'The Digital Geologic Map of the Marin Headlands and Point Reyes Areas, California is composed of GIS data layers complete with ArcMap 9.3 layer (.LYR) files, two ancillary GIS tables, a Map PDF document with ancillary map text, figures and tables, a FGDC metadata record and a 9.3 ArcMap (.MXD) Document that displays the digital map in 9.3 ArcGIS. The data were completed as a component of the Geologic Resources Inventory (GRI) program, a National Park Service (NPS) Inventory and Monitoring (I&M) funded program that is administered by the NPS Geologic Resources Division (GRD). Source geologic maps and data used to complete this GRI digital dataset were provided by the following: USGS and California Geological Survey. Detailed information concerning the sources used and their contribution the GRI product are listed in the Source Citation sections(s) of this metadata record (mhpr_metadata.txt; available at http://nrdata.nps.gov/goga/nrdata/geology/gis/mhpr_metadata.xml). All GIS and ancillary tables were produced as per the NPS GRI Geology-GIS Geodatabase Data Model v. 2.1. (available at: http://science.nature.nps.gov/im/inventory/geology/GeologyGISDataModel.cfm). The GIS data is available as a 9.3 personal geodatabase (mhpr_geology.mdb), and as shapefile (.SHP) and DBASEIV (.DBF) table files. The GIS data projection is NAD83, UTM Zone 10N. That data is within the area of interest of Golden Gate National Recreation Area, Point Reyes National Seashore and Muir Woods National Monument.', 'urls': [ 'https://data.doi.gov/dataset/digital-geologic-map-of-the-marin-headlands-and-point-reyes-areas-california-nps-grd-gri-g', 'https://catalog.data.gov/dataset/digital-geologic-map-of-the-marin-headlands-and-point-reyes-areas-california-nps-grd-gri-goga-p' ] } )
coll.insert_one ( { 'topic':'Maps', '6th dataset': 'Digital Geologic Map of Big Hole National Battlefield and Vicinity, Montana (NPS, GRD, GRI, BIHO, NEPE, BIHO digital map)', 'license': 'NA', 'description': 'The Digital Geologic Map of Big Hole National Battlefield and Vicinity, Montana is composed of GIS data layers complete with ArcMap 9.3 layer (.LYR) files, two ancillary GIS tables, a map help document in PDF format with ancillary map text, figures and tables, a FGDC metadata record and a 9.3 ArcMap (.MXD) Document that displays the digital map in 9.3 ArcGIS. The data were completed as a component of the Geologic Resources Inventory (GRI) program, a National Park Service (NPS) Inventory and Monitoring (I&M) funded program that is administered by the NPS Geologic Resources Division (GRD). Source geologic maps and data used to complete this GRI digital dataset were provided by the following: U.S. Geological Survey. Detailed information concerning the sources used and their contribution the GRI product are listed in the Source Citation sections(s) of this metadata record (biho_metadata.txt; available at http://nrdata.nps.gov/biho/nrdata/geology/gis/biho_metadata.xml). All GIS and ancillary tables were produced as per the NPS GRI Geology-GIS Geodatabase Data Model v. 2.1. (available at: http://science.nature.nps.gov/im/inventory/geology/GeologyGISDataModel.cfm). The GIS data is available as a 9.3 personal geodatabase (biho_geology.mdb), and as shapefile (.SHP) and DBASEIV (.DBF) table files. The GIS data projection is NAD83, UTM Zone 12N. That data is within the area of interest of Big Hole National Battlefield and Nez Perce National Historical Park.', 'urls': [ 'https://data.doi.gov/dataset/digital-geologic-map-of-big-hole-national-battlefield-and-vicinity-montana-nps-grd-gri-bih', 'https://catalog.data.gov/dataset/digital-geologic-map-of-big-hole-national-battlefield-and-vicinity-montana-nps-grd-gri-biho-nep', 'https://data.wu.ac.at/schema/data_gov/MjdmODZiYjgtZTdhYy00NWFlLTlkZjQtOTJkNmY4YTI0MzJk' ] } )
coll.insert_one ( { 'topic':'Maps', '7th dataset': 'Geological map of the Arctic, 1:5 000 000', 'license': 'Rights under which the catalog can be reused are outlined in the Open Government Licence - Canada', 'description': 'As part of the International Polar Year (IPY) 200708 and 200809 activities, and related objectives of the Commission for the Geological Map of the World (CGMW), nations of the circumpolar Arctic have co-operated to produce a new bedrock geology map and related digital map database at a scale of 1:5 000 000. The map, released in north polar stereographic projection using the World Geodetic System (WGS) 84 datum, includes complete geological and physiographic coverage of all onshore and offshore bedrock areas north of latitude 60° north.', 'urls': [ 'https://open.canada.ca/data/en/dataset/9f4aacbb-42eb-be93-f0a0-9a30cf6d658f' ] } )
coll.insert_one ( { 'topic':'Maps', '8th dataset': 'Digital Geological Maps of the Dutch Continental Shelf, North Sea (1992-)', 'license': 'https://vocab.nerc.ac.uk/collection/L08/current/NC/', 'description': 'The geological inventory of The Netherlands is one of the tasks of the NIAG. Its aim is to map the subsoil (quaternary, Tertiary) of the southern North Sea. The maps have been made using contouring/mapping (ZMAP+) and GIS (Arc/Info) software.', 'urls': [ 'https://www.bodc.ac.uk/resources/inventories/edmed/report/2986/', 'https://edmed.seadatanet.org/report/2986/' ] } )
coll.insert_one ( { 'topic':'Maps', '9th dataset': 'Utah Geology Maps (Utah FORGE)', 'license': 'NA', 'description': 'This is a link to Utah geology maps in both pdf and GIS formats. This includes the geology of the Utah FORGE area. This site is maintained by the Utah Geological Survey.', 'urls': [ 'https://catalog.data.gov/dataset/utah-geology-maps-utah-forge', 'https://data.wu.ac.at/schema/data_gov/NjE3ODRlZGMtYzQxZS00YjJiLWIwM2UtNzNmOTk5N2RjNDc1' ] } )
coll.insert_one ( { 'topic':'Maps', '10th dataset': 'Geological Map of the Baltic Sea Bottom, 1:200,000 (1976-90)', 'license': 'https://vocab.nerc.ac.uk/collection/L08/current/MO/', 'description': 'During 1976-1990, ca 30,000 km of echosounding profiles were carried out and ca 7000 km of shallow seismic lines, 6051 samples of surface bottom deposits and 827 cores were taken. Also, 23 boreholes were made. Standard investigations in the laboratory were done including: 8850 analyses of grain size distributions, ca 3570 content of heavy minerals and ca 2150 composition of heavy minerals. Also, 14C, TL, pollen and diatomological analyses were carried out. The results of cruises and laboratory work are presented on 12 sheets of maps, which contain: the map of bottom sediments (scale 1:200,000), geological cross-sections, geological profiles, and maps (scale 1:500,000) of geomorphology, lithodynamics, sediments 1m below the bottom surface, and mineral resources (legends are in Polish and English). There is also an explanatory booklet for each sheet of the map (in Polish only). The results of cruises and laboratory work are also stored in a computer database (Fox-Pro). Only echograms and shallow seismic records are in hard copies.', 'urls': [ 'https://www.bodc.ac.uk/resources/inventories/edmed/report/1663/', 'https://edmed.seadatanet.org/report/1663/' ] } )
coll.insert_one ( { 'topic':'Maps', '11th dataset': '1:100,000 Geological series map - Ninghan (2339)', 'license': 'Creative Commons Attribution 4.0', 'description': 'Detailed geological mapping at 1:100 000 providing information on geological units, structural geology and fault lines, to produce a geological plan of the Ninghan region of Western Australia', 'urls': [ 'https://data.gov.au/dataset/ds-wa-1fdde9ce-0c11-448a-9081-fdc6021c1073' ] } )
coll.insert_one ( { 'topic':'Maps', '12th dataset': 'Geologic map database of Texas (NGMDB)', 'license': 'NA', 'description': 'This record is maintained in the National Geologic Map Database (NGMDB). The NGMDB is a Congressionally mandated national archive of geoscience maps, reports, and stratigraphic information, developed according to standards defined by the cooperators, i.e., the USGS and the Association of American State Geologists (AASG). Included in this system is a comprehensive set of publication citations, stratigraphic nomenclature, downloadable content, unpublished source information, and guidance on standards development. The NGMDB contains information on more than 90,000 maps and related geoscience reports published from the early 1800s to the present day, by more than 630 agencies, universities, associations, and private companies. For more information, please see http://ngmdb.usgs.gov/.', 'urls': [ 'https://catalog.data.gov/dataset/geologic-map-database-of-texas-ngmdb' ] } )
coll.insert_one ( { 'topic':'Maps', '13th dataset': 'Digital Geologic Map of Utah (NGMDB)', 'license': 'NA', 'description': 'This record is maintained in the National Geologic Map Database (NGMDB). The NGMDB is a Congressionally mandated national archive of geoscience maps, reports, and stratigraphic information, developed according to standards defined by the cooperators, i.e., the USGS and the Association of American State Geologists (AASG). Included in this system is a comprehensive set of publication citations, stratigraphic nomenclature, downloadable content, unpublished source information, and guidance on standards development. The NGMDB contains information on more than 90,000 maps and related geoscience reports published from the early 1800s to the present day, by more than 630 agencies, universities, associations, and private companies. For more information, please see http://ngmdb.usgs.gov/.', 'urls': [ 'https://catalog.data.gov/dataset/digital-geologic-map-of-utah-ngmdb'] } )
coll.insert_one ( { 'topic':'Maps', '14th dataset': 'Geological Provinces (Nunavut)', 'license': 'Rights under which the catalog can be reused are outlined in the Open Government Licence - Canada', 'description': 'A geological province is an extensive region characterized by rocks and structures of varying types and ages. Canada has seventeen geological provinces consisting of a shield, platforms, orogens and continental shelves. Nunavut includes four of the geological provinces: Innuitian Orogen, Arctic Platform, Hudson Bay Lowlands, and Bear Province.', 'urls': [ 'https://open.canada.ca/data/en/dataset/e6d7b061-8893-11e0-a7c8-6cf049291510', 'https://data.wu.ac.at/schema/www_data_gc_ca/ZTZkN2IwNjEtODg5My0xMWUwLWE3YzgtNmNmMDQ5MjkxNTEw' ] } )
coll.insert_one ( { 'topic':'Maps', '15th dataset': 'Geologic map of Wyoming (NGMDB)', 'license': 'NA', 'description': 'This record is maintained in the National Geologic Map Database (NGMDB). The NGMDB is a Congressionally mandated national archive of geoscience maps, reports, and stratigraphic information, developed according to standards defined by the cooperators, i.e., the USGS and the Association of American State Geologists (AASG). Included in this system is a comprehensive set of publication citations, stratigraphic nomenclature, downloadable content, unpublished source information, and guidance on standards development. The NGMDB contains information on more than 90,000 maps and related geoscience reports published from the early 1800s to the present day, by more than 630 agencies, universities, associations, and private companies. For more information, please see http://ngmdb.usgs.gov/.', 'urls': [ 'https://catalog.data.gov/dataset/geologic-map-of-wyoming-ngmdb' ] } )
coll.insert_one ( { 'topic':'Maps', '16th dataset': 'Geologic map of Kentucky (NGMDB)', 'license': 'NA', 'description': 'This record is maintained in the National Geologic Map Database (NGMDB). The NGMDB is a Congressionally mandated national archive of geoscience maps, reports, and stratigraphic information, developed according to standards defined by the cooperators, i.e., the USGS and the Association of American State Geologists (AASG). Included in this system is a comprehensive set of publication citations, stratigraphic nomenclature, downloadable content, unpublished source information, and guidance on standards development. The NGMDB contains information on more than 90,000 maps and related geoscience reports published from the early 1800s to the present day, by more than 630 agencies, universities, associations, and private companies. For more information, please see http://ngmdb.usgs.gov/.', 'urls': [ 'https://catalog.data.gov/dataset/geologic-map-of-kentucky-ngmdb' ] } )
coll.insert_one ( { 'topic':'Maps', '17th dataset': 'Geologic map of Mississippi (NGMDB)', 'license': 'NA', 'description': 'This record is maintained in the National Geologic Map Database (NGMDB). The NGMDB is a Congressionally mandated national archive of geoscience maps, reports, and stratigraphic information, developed according to standards defined by the cooperators, i.e., the USGS and the Association of American State Geologists (AASG). Included in this system is a comprehensive set of publication citations, stratigraphic nomenclature, downloadable content, unpublished source information, and guidance on standards development. The NGMDB contains information on more than 90,000 maps and related geoscience reports published from the early 1800s to the present day, by more than 630 agencies, universities, associations, and private companies. For more information, please see http://ngmdb.usgs.gov/.', 'urls': [ 'https://catalog.data.gov/dataset/geologic-map-of-mississippi-ngmdb' ] } )
coll.insert_one ( { 'topic':'Maps', '18th dataset': 'Geologic map of Colorado (NGMDB)', 'license': 'NA', 'description': 'This record is maintained in the National Geologic Map Database (NGMDB). The NGMDB is a Congressionally mandated national archive of geoscience maps, reports, and stratigraphic information, developed according to standards defined by the cooperators, i.e., the USGS and the Association of American State Geologists (AASG). Included in this system is a comprehensive set of publication citations, stratigraphic nomenclature, downloadable content, unpublished source information, and guidance on standards development. The NGMDB contains information on more than 90,000 maps and related geoscience reports published from the early 1800s to the present day, by more than 630 agencies, universities, associations, and private companies. For more information, please see http://ngmdb.usgs.gov/.', 'urls': [ 'https://catalog.data.gov/dataset/geologic-map-of-colorado-ngmdb'] } )
coll.insert_one ( { 'topic':'Maps', '19th dataset': 'Geologic map of Yellowstone National Park (NGMDB)s', 'license': 'NA', 'description': 'This record is maintained in the National Geologic Map Database (NGMDB). The NGMDB is a Congressionally mandated national archive of geoscience maps, reports, and stratigraphic information, developed according to standards defined by the cooperators, i.e., the USGS and the Association of American State Geologists (AASG). Included in this system is a comprehensive set of publication citations, stratigraphic nomenclature, downloadable content, unpublished source information, and guidance on standards development. The NGMDB contains information on more than 90,000 maps and related geoscience reports published from the early 1800s to the present day, by more than 630 agencies, universities, associations, and private companies. For more information, please see http://ngmdb.usgs.gov/.', 'urls': [ 'https://catalog.data.gov/dataset/geologic-map-of-yellowstone-national-park-ngmdb'] } )
coll.insert_one ( { 'topic':'Maps', '20th dataset': 'Digital bedrock geologic map of the Rochester quadrangle, Vermont (NGMDB)', 'license': 'NA', 'description': 'This record is maintained in the National Geologic Map Database (NGMDB). The NGMDB is a Congressionally mandated national archive of geoscience maps, reports, and stratigraphic information, developed according to standards defined by the cooperators, i.e., the USGS and the Association of American State Geologists (AASG). Included in this system is a comprehensive set of publication citations, stratigraphic nomenclature, downloadable content, unpublished source information, and guidance on standards development. The NGMDB contains information on more than 90,000 maps and related geoscience reports published from the early 1800s to the present day, by more than 630 agencies, universities, associations, and private companies. For more information, please see http://ngmdb.usgs.gov/.', 'urls': [ 'https://catalog.data.gov/dataset/digital-bedrock-geologic-map-of-the-rochester-quadrangle-vermont-ngmdb' ] } )

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['smaniko1']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
