# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['cmetzner']
# for each dataset
coll.insert_one ( { 'Topic':'Alcohol Consumption', 'Title': 'Alcohol Consumption', 'License': 'Creative Commons Attribution 4.0 International License', 'Description': 'This repository contains a selection of the data -- and the data-processing scripts -- behind the articles, graphics and interactives at FiveThirtyEight.', 'urls': [ 'https://data.world/fivethirtyeight/alcohol-consumption' ] } )

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['cmetzner']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d87a6beac142f5715633b6a'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
#  'urls': ['url1', 'url2']}
# {'Description': 'This dataset gives the information regarding '
#                 'the life expectancy of people of different '
#                 'countries with different levels of pure '
#                 'alcohol consumption.',
#  'License': 'NA',
#  'Title': 'Alcohol vs Life Expectancy',
#  'Topic': 'Alcohol Consumption',
#  '_id': ObjectId('5d87ac01ac142f5715633b6d'),
#  'urls': ['https://data.world/hhaveliw/alcohol-vs-life-expectancy']}
# {'Description': 'This statistic shows the volume of beer '
#                 'consumed per capita in Europe in 2017, broken '
#                 'down by country.',
#  'License': 'NA',
#  'Title': 'Volume of beer consumed per capita in Europe in 2017',
# ...

# %%
coll.count()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   """Entry point for launching an IPython kernel.
# 21
