# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['twelles']
# for each dataset
coll.insert_one ( { 'topic':'electric vehicles', 'title': 'Electric Vehicle Population Data', 'license': 'NA', 'description': 'This dataset shows the Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs) that are currently registered through Washington State Department of Licensing (DOL).', 'urls': [ 'https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD' ] } )
coll.insert_one ( { 'topic':'electric vehicles', 'title': 'Electric Vehicles Charging Points', 'license': 'Open Government License 3.0', 'description': 'Chariging Points for electric vehicles in York', 'urls': [ 'https://opendata.arcgis.com/datasets/f90c488ea93644d5a734a8995a080ef0_18.csv' ] } )
coll.insert_one ( { 'topic':'electric vehicles', 'title': 'Electric Vehicle Population Size History', 'license': 'NA', 'description': 'Number of EVs registered by DOL each month', 'urls': [ 'https://data.wa.gov/api/views/d886-d5q2/rows.csv?accessType=DOWNLOAD' ] } )
coll.insert_one ( { 'topic':'electric vehicles', 'title': 'Electric Vehicle Title and Registration Activity', 'license': 'NA', 'description': 'title activity', 'urls': [ 'https://data.wa.gov/api/views/rpr4-cgyd/rows.csv?accessType=DOWNLOAD' ] } )
coll.insert_one ( { 'topic':'electric vehicles', 'title': 'Smart-Grid Smart-City Electric Vehicle Trial Data', 'license': 'Creative Commons Attribution 3.0 Australia', 'description': 'EV data from Smart Grid Smart City project', 'urls': [ 'https://data.gov.au/dataset/87f276c3-5fba-4f31-9032-199793d6f4a7/resource/5092c15c-a5c6-4a6f-bb40-492028470fc0/download/sgsc-ev-electric-vehicles-data.csv' ] } )
coll.insert_one ( { 'topic':'electric vehicles', 'title': 'Public Charging Stations for Electric Vehicles', 'license': 'NA', 'description': 'details of electric charging stations available for public use', 'urls': [ 'https://data.edmonton.ca/api/views/xzhy-xe8z/rows.csv?accessType=DOWNLOAD' ] } )
coll.insert_one ( { 'topic':'electric vehicles', 'title': 'Plug-in EVerywhere Charging Station Network', 'license': 'NA', 'description': 'details about Austin Energy plug-in stations', 'urls': [ 'https://data.austintexas.gov/api/views/k5hp-eece/rows.csv?accessType=DOWNLOAD' ] } )
coll.insert_one ( { 'topic':'electric vehicles', 'title': 'Data from: Economic and Climate benefits of electric vehicles in China, the United States and Germany', 'license': 'CC BY-NC 4.0', 'description': 'looks at range and battery data from EVs', 'urls': [ 'https://ndownloader.figshare.com/files/17483072' ] } )
coll.insert_one ( { 'topic':'electric vehicles', 'title': 'Data from: impact of uncoordinated plug-in electric vehicle charging on residential power demand - supplementary data', 'license': 'NA', 'description': 'electricity demand profiles of households', 'urls': [ 'https://www.osti.gov/servlets/purl/1363870' ] } )
coll.insert_one ( { 'topic':'electric vehicles', 'title': 'Electric Vehicle Charging Stations', 'license': 'NA', 'description': 'locations of chargers', 'urls': [ 'https://data.cityoftacoma.org/api/views/qzgd-rmfq/rows.csv?accessType=DOWNLOAD'] } )
coll.insert_one ( { 'topic':'electric vehicles', 'title': 'Electric Vehicle Charging Stations', 'license': 'Public Domain', 'description': 'existing charging stations', 'urls': [ 'https://data.ct.gov/api/views/88b5-ii6i/rows.csv?accessType=DOWNLOAD' ] } )
coll.insert_one ( { 'topic':'electric vehicles', 'title': 'Public Electric Vehicle Charging Stations and Alternative Fuel Stations in Maryland', 'license': 'NA', 'description': 'EV charging stations and alternative refueling stations', 'urls': [ 'https://opendata.maryland.gov/api/views/843n-d2np/rows.csv?accessType=DOWNLOAD' ] } )
coll.insert_one ( { 'topic':'electric vehicles', 'title': 'Find a charging station — Electric vehicle', 'license': 'Creative Commons Attribution 4.0', 'description': 'location of EV chargers in Queensland', 'urls': [ 'http://www.tmr.qld.gov.au/-/media/aboutus/corpinfo/Open%20data/findachargingev/csl_ev.csv' ] } )
coll.insert_one ( { 'topic':'electric vehicles', 'title': 'Electric Vehicle Charging Stations', 'license': 'refernce only', 'description': 'locations of chargers in large cities in China', 'urls': [ 'https://opendata.arcgis.com/datasets/2daa28151e9146aabbe1cd01fc13a043_0.kml' ] } )
coll.insert_one ( { 'topic':'electric vehicles', 'title': 'Replication Data for: Calculating operational patterns for electric vehicle charging on a real distribution network based on renewables’ production', 'license': 'CC0', 'description': 'provides data to help with location of chargers', 'urls': [ 'https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/1MWESP#' ] } )
coll.insert_one ( { 'topic':'electric vehicles', 'title': 'Electric Vehicle Charging Stations', 'license': 'Public Domain', 'description': 'location, type and access info for EV chargers', 'urls': [ 'https://data.smcgov.org/api/views/k4h3-yhwc/rows.csv?accessType=DOWNLOAD' ] } )
coll.insert_one ( { 'topic':'electric vehicles', 'title': 'ENERGY STAR Certified Electric Vehicle Supply Equipment', 'license': 'NA', 'description': 'list of EV supply equipment', 'urls': [ 'https://data.energystar.gov/api/views/y2tt-wp6c/rows.csv?accessType=DOWNLOAD' ] } )
coll.insert_one ( { 'topic':'electric vehicles', 'title': 'Replication Data for: A new probabilistic method for providing meshed distribution network operational points after reinforcement for the connection of electric vehicles', 'license': 'CC0', 'description': 'EV charger possible locations', 'urls': [ 'https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/KVFPKH#' ] } )
coll.insert_one ( { 'topic':'electric vehicles', 'title': 'Electric Vehicle Charging Stations', 'license': 'open data license', 'description': 'locations of EV chargers', 'urls': [ 'https://opendata.arcgis.com/datasets/4bd933131dbd4b7b9ca69b2ac89835c4_8.csv?outSR=%7B%22latestWkid%22%3A3157%2C%22wkid%22%3A3157%7D' ] } )
coll.insert_one ( { 'topic':'electric vehicles', 'title': 'Electric vehicle charging stations in the city of Barcelona', 'license': 'NA', 'description': 'locations of EV chargers', 'urls': [ 'https://opendata-ajuntament.barcelona.cat/data/dataset/e9da8fe0-5de1-4ca3-97a8-4a8374ded921/resource/6b186e0f-5e38-4beb-8b1d-39dfa9b31053/download' ] } )

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['twelles']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d87d047238c685be2e07e20'),
#  'description': 'This dataset shows the Battery Electric '
#                 'Vehicles (BEVs) and Plug-in Hybrid Electric '
#                 'Vehicles (PHEVs) that are currently registered '
#                 'through Washington State Department of '
#                 'Licensing (DOL).',
#  'license': 'NA',
#  'title': 'Electric Vehicle Population Data',
#  'topic': 'electric vehicles',
#  'urls': ['https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD']}
# {'_id': ObjectId('5d87d048238c685be2e07e21'),
#  'description': 'Chariging Points for electric vehicles in York',
#  'license': 'Open Government License 3.0',
#  'title': 'Electric Vehicles Charging Points',
#  'topic': 'electric vehicles',
#  'urls': ['https://opendata.arcgis.com/datasets/f90c488ea93644d5a734a8995a080ef0_18.csv']}
# {'_id': ObjectId('5d87d048238c685be2e07e22'),
#  'description': 'Number of EVs registered by DOL each month',
#  'license': 'NA',
# ...
