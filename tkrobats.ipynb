# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['tkrobats']

#coll.drop()

# for each dataset
coll.insert_one ( { 'topic':'Particle Physics at LHC',
                   'title': 'Measurement of Z0-boson production at large rapidities in Pb-Pb collisions at sNN−−−√=5.02 TeV',
                   'license': 'Open/Custom https://www.hepdata.net/terms',
                   'description': 'Z-boson candidates are reconstructed in the dimuon decay channel (Z0→μ+μ−), based on muons selected with pseudo-rapidity −4.0<ημ<−2.5 and pμT>20 GeV/c.',
                   'urls': [ 'https://www.hepdata.net/record/ins1639439','https://www.hepdata.net/download/submission/ins1639439/1/yaml' ] } )

coll.insert_one ( { 'topic':'Particle Physics at LHC',
                   'title': 'Transverse momentum spectra and nuclear modification factors of charged particles in pp, p-Pb and Pb-Pb collisions at the LHC',
                   'license': 'Open/Custom https://www.hepdata.net/terms',
                   'description': 'measured transverse momentum (pT) spectra of primary charged particles from pp, p-Pb and Pb-Pb collisions at a center-of-mass energy sNN−−−√=5.02 TeV in the kinematic range of 0.15<pT<50 GeV/c and |η|<0.8',
                   'urls': [ 'https://www.hepdata.net/record/ins1657384','https://www.hepdata.net/download/submission/ins1657384/1/yaml' ] } )

coll.insert_one ( { 'topic':'Particle Physics at LHC',
                   'title': 'Neutral pion and η meson production at mid-rapidity in Pb-Pb collisions at sNN−−−−√ = 2.76 TeV',
                   'license': 'Open/Custom https://www.hepdata.net/terms',
                   'description': 'Neutral pion and η meson production in the transverse momentum range 1 <pT< 20 GeV/c ',
                   'urls': [ 'https://www.hepdata.net/record/ins1662651','https://www.hepdata.net/download/submission/ins1662651/1/yaml' ] } )

coll.insert_one ( { 'topic':'Particle Physics at LHC',
                   'title': 'ϕ  meson production at forward rapidity in Pb-Pb collisions at sNN−−−√=2.76 TeV',
                   'license': 'Open/Custom https://www.hepdata.net/terms',
                   'description': 'measured phi production through its decay in muon pairs in Pb-Pb collisions at SQRT(S_NN) = 2.76 TeV in the intermediate transverse momentum range 2 < PT < 5 GeV/c and in the rapidity interval 2.5 < y <4',
                   'urls': [ 'https://www.hepdata.net/record/ins1669805','https://www.hepdata.net/download/submission/ins1669805/1/yaml' ] } )

coll.insert_one ( { 'topic':'Particle Physics at LHC',
                   'title': 'Υ  suppression at forward rapidity in Pb-Pb collisions at sNN−−−√ = 5.02 TeV',
                   'license': 'Open/Custom https://www.hepdata.net/terms',
                   'description': 'Υ (1S) and Υ(2S) production have been measured in Pb-Pb collisions at the centre-of-mass energy per nucleon-nucleon pair sNN−−−√=5.02 TeV',
                   'urls': [ 'https://www.hepdata.net/record/ins1672798','https://www.hepdata.net/download/submission/ins1672798/1/yaml' ] } )

coll.insert_one ( { 'topic':'Particle Physics at LHC',
                   'title': 'Measurement of D+s production and nuclear modification factor in Pb-Pb collisions at sNN−−−√= 2.76 TeV',
                   'license': 'Open/Custom https://www.hepdata.net/terms',
                   'description': 'The production of prompt D+s mesons was measured for the first time in collisions of heavy nuclei with the ALICE detector at the LHC.',
                   'urls': [ 'https://www.hepdata.net/record/ins1394675','https://www.hepdata.net/download/submission/ins1394675/1/yaml' ] } )

coll.insert_one ( { 'topic':'Particle Physics at LHC',
                   'title': 'Measurement of an excess in the yield of J/ψ at very low pT in Pb-Pb collisions at sNN−−−√ = 2.76 TeV',
                   'license': 'Open/Custom https://www.hepdata.net/terms',
                   'description': 'report on the first measurement of an excess in the yield of J/ψ at very low transverse momentum (pT<0.3 GeV/c) in peripheral hadronic Pb-Pb collisions at sNN−−−√ = 2.76 TeV',
                   'urls': [ 'https://www.hepdata.net/record/ins1395296','https://www.hepdata.net/download/submission/ins1395296/1/yaml' ] } )

coll.insert_one ( { 'topic':'Particle Physics at LHC',
                   'title': 'J/ψ suppression at forward rapidity in Pb-Pb collisions at sNN−−−√=5.02 TeV',
                   'license': 'Open/Custom https://www.hepdata.net/terms',
                   'description': 'The inclusive J/ψ production has been studied in Pb-Pb and pp collisions at the centre-of-mass energy per nucleon pair sNN−−−√=5.02 TeV',
                   'urls': [ 'https://www.hepdata.net/record/ins1472319','https://www.hepdata.net/download/submission/ins1472319/1/yaml'] } )

coll.insert_one ( { 'topic':'Particle Physics at LHC',
                   'title': 'Measurement of the production of high-pT electrons from heavy-flavour hadron decays in Pb-Pb collisions at sNN−−−√ = 2.76 TeV',
                   'license': 'Open/Custom https://www.hepdata.net/terms',
                   'description': 'Electrons from heavy-flavour hadron decays (charm and beauty) were measured with the ALICE detector in Pb-Pb collisions at a centre-of-mass of energy sNN−−−√=2.76 TeV',
                   'urls': [ 'https://www.hepdata.net/record/ins1487727','https://www.hepdata.net/download/submission/ins1487727/1/yaml' ] } )

coll.insert_one ( { 'topic':'Particle Physics at LHC',
                   'title': 'Nuclear modification of electron spectra and implications for heavy quark energy loss in Au+Au collisions at s(NN)**(1/2) - 200-GeV',
                   'license': 'Open/Custom https://www.hepdata.net/terms',
                   'description': 'Measurement by the PHENIX experiment of the transverse momentum spectra (0.4<PT<5.0 GeV/c) ',
                   'urls': [ 'https://www.hepdata.net/record/ins695305','https://www.hepdata.net/download/submission/ins695305/1/yaml' ] } )



coll.insert_one ( { 'topic':'Particle Physics at LHC',
                   'title': 'Energy Loss and Flow of Heavy Quarks in Au+Au Collisions at s(NN)**(1/2) = 200-GeV',
                   'license': 'Open/Custom https://www.hepdata.net/terms',
                   'description': 'Measurements at the PHENIX experiment of electrons with 0.3<PT<9GeV at midrapidity (-0.35<y<0.35) ',
                   'urls': [ 'https://www.hepdata.net/record/ins731668','https://www.hepdata.net/download/submission/ins731668/1/yaml' ] } )

coll.insert_one ( { 'topic':'Particle Physics at LHC',
                   'title': 'J/ψ  Production vs Centrality, Transverse Momentum, and Rapidity in Au+Au Collisions at sNN−−−−√=200 GeV',
                   'license': 'Open/Custom https://www.hepdata.net/terms',
                   'description': 'Measurement of J/PSI production at the PHENIX experiment, in Au+Au collisions at center-of-mass energy of 200GeV, for rapidities,-2.2<y<2.2',
                   'urls': [ 'https://www.hepdata.net/record/ins731670','https://www.hepdata.net/download/submission/ins731670/1/yaml' ] } )

coll.insert_one ( { 'topic':'Particle Physics at LHC',
                   'title': 'Transverse momentum and centrality dependence of high-pT non-photonic electron suppression in Au+Au collisions at sNN−−−−√=200\,GeV',
                   'license': 'Open/Custom https://www.hepdata.net/terms',
                   'description': 'Measurement by the STAR collaboration of the inclusive yield of non photonic electrons, which arise dominantly from semi-leptonic decays of heavy flavor mesons, over a range of transverse momenta',
                   'urls': [ 'https://www.hepdata.net/record/ins721275','https://www.hepdata.net/download/submission/ins721275/1/yaml' ] } )

coll.insert_one ( { 'topic':'Particle Physics at LHC',
                   'title': 'J/psi production at high transverse momentum in p+p and Cu+Cu collisions at s(NN)**1/2 = 200GeV',
                   'license': 'Open/Custom https://www.hepdata.net/terms',
                   'description': 'STAR-RHIC. J/psi production in p+p and Cu+Cu collisions at sqrt(s) = 200 GeV, for high transverse momentum (above 5 GeV/c) and at mid-rapidity',
                   'urls': [ 'https://www.hepdata.net/record/ins817120','https://www.hepdata.net/download/submission/ins817120/1/yaml' ] } )

coll.insert_one ( { 'topic':'Particle Physics at LHC',
                   'title': 'Observation of D0 Meson Nuclear Modifications in Au+Au Collisions at sNN−−−−√=200  GeV',
                   'license': 'Open/Custom https://www.hepdata.net/terms',
                   'description': 'BNL-RHIC.  We report the first measurement of charmed-hadron (D0) production via the hadronic decay channel (D0→K−+π+) in Au+Au collisions at sNN−−−√ = 200\,GeV with the STAR experiment',
                   'urls': [ 'https://www.hepdata.net/record/ins1292132','https://www.hepdata.net/download/submission/ins1292132/1/yaml' ] } )

coll.insert_one ( { 'topic':'Particle Physics at LHC',
                   'title': 'Charged-particle nuclear modification factors in XeXe collisions at sNN−−−√=5.44 TeV',
                   'license': 'Open/Custom https://www.hepdata.net/terms',
                   'description': 'The differential yields of charged particles having pseudorapidity within |η| < 1 are measured using xenon-xenon (XeXe) collisions at sNN−−−√=5.44 TeV',
                   'urls': [ 'https://www.hepdata.net/record/ins1692558','https://www.hepdata.net/download/submission/ins1692558/1/yaml' ] } )

coll.insert_one ( { 'topic':'Particle Physics at LHC',
                   'title': 'Nuclear modification factor of D0 mesons in PbPb collisions at sqrt(s[NN]) = 5.02 TeV',
                   'license': 'Open/Custom https://www.hepdata.net/terms',
                   'description': 'he measurement is performed in the D0 meson pt range of 2-100 GeV and in the rapidity range of abs(y)<1',
                   'urls': [ 'https://www.hepdata.net/record/ins1616207','https://www.hepdata.net/download/submission/ins1616207/1/yaml' ] } )

coll.insert_one ( { 'topic':'Particle Physics at LHC',
                   'title': 'Charged-particle nuclear modification factors in PbPb and pPb collisions at sNN−−−√= 5.02 TeV',
                   'license': 'Open/Custom https://www.hepdata.net/terms',
                   'description': 'he spectra of charged particles produced within the pseudorapidity window |η|< 1 at sNN−−−√= 5.02 TeV are measured',
                   'urls': [ 'https://www.hepdata.net/record/ins1496050','https://www.hepdata.net/download/submission/ins1496050/1/yaml' ] } )

coll.insert_one ( { 'topic':'Particle Physics at LHC',
                   'title': 'Suppression of Υ(1S), Υ(2S) and Υ(3S) production in PbPb collisions at sNN−−−−√ = 2.76 TeV',
                   'license': 'Open/Custom https://www.hepdata.net/terms',
                   'description': 'The production yields of Υ(1S), Υ(2S), and Υ(3S) quarkonium states are measured through their decays into muon pairs in the CMS detector',
                   'urls': [ 'https://www.hepdata.net/record/ins1495866','https://www.hepdata.net/download/submission/ins1495866/1/yaml' ] } )

coll.insert_one ( { 'topic':'Particle Physics at LHC',
                   'title': 'Transverse momentum spectra in Au+Au and d+Au collisions at s**(1/2) = 200-GeV and the pseudorapidity dependence of high p(T) suppression',
                   'license': 'Open/Custom https://www.hepdata.net/terms',
                   'description': 'BNL-RHIC-BRAHMS. We present spectra of charged hadrons from Au+Au and d+Au collisions at sNN−−−−√=200 GeV measured with the BRAHMS experiment at RHIC',
                   'urls': [ 'https://www.hepdata.net/record/ins622645','https://www.hepdata.net/download/submission/ins622645/1/yaml' ] } )

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['tkrobats']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d850190baff23a7b357dac4'),
#  'description': 'Z-boson candidates are reconstructed in the '
#                 'dimuon decay channel (Z0→μ+μ−), based on muons '
#                 'selected with pseudo-rapidity −4.0<ημ<−2.5 and '
#                 'pμT>20 GeV/c.',
#  'license': 'Open/Custom https://www.hepdata.net/terms',
#  'title': 'Measurement of Z0-boson production at large '
#           'rapidities in Pb-Pb collisions at sNN−−−√=5.02 TeV',
#  'topic': 'Particle Physics at LHC',
#  'urls': ['https://www.hepdata.net/record/ins1639439',
#           'https://www.hepdata.net/download/submission/ins1639439/1/yaml']}
# {'_id': ObjectId('5d850190baff23a7b357dac5'),
#  'description': 'measured transverse momentum (pT) spectra of '
#                 'primary charged particles from pp, p-Pb and '
#                 'Pb-Pb collisions at a center-of-mass energy '
#                 'sNN−−−√=5.02 TeV in the kinematic range of '
#                 '0.15<pT<50 GeV/c and |η|<0.8',
# ...
