# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['yma29']
# for each dataset
coll.insert_one ( {'topic':'Pokemon', 'first dataset': 'The Complete Pokemon Dataset', 'license': 'CC0: Public Domain', 'description': 'This dataset contains information on all 802 Pokemon from all Seven Generations of Pokemon. ', 'urls': [ 'https://www.kaggle.com/rounakbanik/pokemon'] } )
coll.insert_one ( {'topic':'Pokemon', 'second dataset': 'Pokémon for Data Mining and Machine Learning', 'license': 'CC BY-NC-SA 4.0', 'description': 'With the rise of the popularity of machine learning, this is a good opportunity to share a wide database of the even more popular video-game Pokémon by Nintendo, Game freak, and Creatures, originally released in 1996. ', 'urls': [ 'https://www.kaggle.com/alopez247/pokemon'] } )
coll.insert_one ( {'topic':'Pokemon', 'third dataset': 'Pokemon with stats', 'license': 'CC0: Public Domain', 'description': 'This data set includes 721 Pokemon, including their number, name, first and second type, and basic stats:', 'urls': [ 'https://www.kaggle.com/abcsds/pokemon'] } )
coll.insert_one ( {'topic':'Pokemon', '4th dataset': ' Pokemon- Weedle Cave ', 'license': 'CC0: Public Domain', 'description': 'To do it you will have the pokemon characteristics and the results of previous combats. ', 'urls': [ 'https://www.kaggle.com/terminus7/pokemon-challenge'] } )
coll.insert_one ( {'topic':'Pokemon', '5th dataset': ' Pokemon Generation One ', 'license': ' GPL 2', 'description': ' The dataset was built out of necessity as there was not much sanitised data available online for images of Pokemon based on their Generation and names. ', 'urls': [ 'https://www.kaggle.com/thedagger/pokemon-generation-one'] } )
coll.insert_one ( {'topic':'Pokemon', '6th dataset': ' Pokemon Image Dataset ', 'license': 'Attribution 4.0 International (CC BY 4.0)', 'description': ' Images of all Pokemon ', 'urls': [ 'https://www.kaggle.com/vishalsubbiah/pokemon-images-and-types'] } )
coll.insert_one ( {'topic':'Pokemon', '7th dataset': ' Pokemon ', 'license': 'CC0: Public Domain', 'description': ' Pokemon data to be used to teach exploratory data analysis. ', 'urls': [ 'https://www.kaggle.com/mlomuscio/pokemon'] } )
coll.insert_one ( {'topic':'Pokemon', '8th dataset': ' Pokemon Images Dataset ', 'license': 'CC0: Public Domain', 'description': ' Dataset of 819 Pokemon images', 'urls': [ 'https://www.kaggle.com/kvpratama/pokemon-images-dataset'] } )
coll.insert_one ( {'topic':'Pokemon', '9th dataset': ' Pokemon Sun and Moon (Gen 7) Stats ', 'license': 'N/A', 'description': ' Explore all 802 Pokemon from the newly released 7th Generation ', 'urls': [ 'https://www.kaggle.com/mylesoneill/pokemon-sun-and-moon-gen-7-stats'] } )
coll.insert_one ( {'topic':'Pokemon', '10th dataset': ' Predict,em All ', 'license': '', 'description': 'Predict where Pokemon appear in PokemonGo based on historical data', 'urls': [ 'https://www.kaggle.com/semioniy/predictemall'] } )
coll.insert_one ( {'topic':'Pokemon', '11th dataset': ' One-Shot-Pokemon Images ', 'license': 'CC0: Public Domain', 'description': 'Colorful and fun dataset for one shot learning problem, gotta recognize them all ', 'urls': [ 'https://www.kaggle.com/aaronyin/oneshotpokemon'] } )
coll.insert_one ( {'topic':'Pokemon', '12th dataset': ' PokemonGO ', 'license': 'CC0: Public Domain', 'description': ' 151 Pokemon and battle stats ', 'urls': [ 'https://www.kaggle.com/abcsds/pokemongo'] } )
coll.insert_one ( {'topic':'Pokemon', '13rd dataset': ' Complete Pokemon Image Dataset ', 'license': 'CC0: Public Domain', 'description': ' Pokemon image ', 'urls': [ 'https://www.kaggle.com/mrgravelord/complete-pokemon-image-dataset'] } )
coll.insert_one ( {'topic':'Pokemon', '14th dataset': ' SF Bay Area Pokemon Go Spawns ', 'license': 'Database: Open Database, Contents: Database Contents', 'description': ' Find patterns in spawn location, type and time', 'urls': [ 'https://www.kaggle.com/kveykva/sf-bay-area-pokemon-go-spawns'] } )
coll.insert_one ( {'topic':'Pokemon', '15th dataset': ' Pokemon Trainers Dataset ', 'license': 'CC0: Public Domain', 'description': ' A collection of images of the original 151 Pokemon obtained through Bing search', 'urls': [ 'https://www.kaggle.com/brkurzawa/original-150-pokemon-image-search-results'] } )
coll.insert_one ( {'topic':'Pokemon', '16th dataset': ' Original 151 Pokemon Image Search Results ', 'license': 'GPL2', 'description': '  ', 'urls': [ 'https://www.kaggle.com/brkurzawa/original-150-pokemon-image-search-results'] } )
coll.insert_one ( {'topic':'Pokemon', '17th dataset': ' Pokemon Images ', 'license': 'CC0: Public Domain', 'description': ' Pokemon images ', 'urls': [ 'https://www.kaggle.com/dollarakshay/pokemon-images'] } )
coll.insert_one ( {'topic':'Pokemon', '18th dataset': ' Complete Competitive Pokemon Dataset ', 'license': '', 'description': ' 7th Generation including Mega Evolutions and Alolan forms ', 'urls': [ 'https://www.kaggle.com/n2cholas/competitive-pokemon-dataset'] } )
coll.insert_one ( {'topic':'Pokemon', '19th dataset': ' Pokemon Data (gen VII included) ', 'license': 'CC0: Public Domain', 'description': ' Pokédex information for Pokemons up to gen VII ', 'urls': [ 'https://www.kaggle.com/kronostheus/pokemon-data'] } )
coll.insert_one ( {'topic':'Pokemon', '20th dataset': ' 1st to 7th Gen Pokemon ', 'license': 'CC0: Public Domain', 'description': ' All Pokemon up to 7th Gen with stats ', 'urls': [ ' https://www.kaggle.com/dizzypanda/1st-to-7th-gen-pokemon '] } )

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['yma29']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d84e50578087429428d8730'),
#  'description': 'This dataset contains information on all 802 '
#                 'Pokemon from all Seven Generations of '
#                 'Pokemon. ',
#  'first dataset': 'The Complete Pokemon Dataset',
#  'license': 'CC0: Public Domain',
#  'topic': 'Pokemon',
#  'urls': ['https://www.kaggle.com/rounakbanik/pokemon']}
# {'_id': ObjectId('5d84e53778087429428d8734'),
#  'description': 'This dataset contains information on all 802 '
#                 'Pokemon from all Seven Generations of '
#                 'Pokemon. ',
#  'first dataset': 'The Complete Pokemon Dataset',
#  'license': 'CC0: Public Domain',
#  'topic': 'Pokemon',
#  'urls': ['https://www.kaggle.com/rounakbanik/pokemon']}
# {'_id': ObjectId('5d84e53b78087429428d8736'),
#  'description': 'This dataset contains information on all 802 '
#                 'Pokemon from all Seven Generations of '
#                 'Pokemon. ',
# ...
