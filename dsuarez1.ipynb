# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['dsuarez1']
# for each dataset
coll.insert_one ( { 'topic':'Atlanta Education', 'first dataset': 'All Employees: Educational Services in Atlanta-Sandy Springs-Roswell, GA (MSA)', 'license': 'https://research.stlouisfed.org/fred_terms.html', 'description': 'Graph and download economic data for All Employees: Educational Services in Atlanta-Sandy Springs-Roswell, GA (MSA) (SMU13120606561000001SA) from Jan 1990 to Jul 2019 about Atlanta, GA, education, services, employment, and USA.', 'urls': [ 'https://fred.stlouisfed.org/series/SMU13120606561000001SA'] } )
coll.insert_one ( { 'topic':'Atlanta Education', 'second dataset': 'Bachelor\'s Degree or Higher (5-year estimate) in Clayton County, GA)', 'license': 'https://research.stlouisfed.org/fred_terms.html', 'description': 'Graph and download economic data for Bachelor\'s Degree or Higher (5-year estimate) in Clayton County, GA (HC01ESTVC1713063) from 2010 to 2017 about Clayton County, GA; educational attainment; Atlanta; tertiary schooling; GA; education; 5-year; and USA.', 'urls': [ 'https://fred.stlouisfed.org/series/HC01ESTVC1713063'] } )
coll.insert_one ( { 'topic':'Atlanta Education', 'third dataset': 'All Employees: Education and Health Services in Atlanta-Sandy Springs-Roswell, GA (MSA)', 'license': 'https://research.stlouisfed.org/fred_terms.html', 'description': 'Graph and download economic data for All Employees: Education and Health Services in Atlanta-Sandy Springs-Roswell, GA (MSA) (ATLA013EDUHN) from Jan 1990 to Jul 2019 about Atlanta, health, GA, education, services, employment, and USA.', 'urls': [ 'https://fred.stlouisfed.org/series/ATLA013EDUHN'] } )
coll.insert_one ( { 'topic':'Atlanta Education', 'fourth dataset': 'City of Atlanta City Council Districts (Weave Interactive Map)', 'license': 'http://creativecommons.org/licenses/by/4.0', 'description': 'This interactive map, part of the City of Atlanta Data Visualization Suite, displays about 400 indicators for the City of Atlanta’s Council Districts. In addition to U.S. Census data, the map includes city-specific data such as code enforcement, housing conditions, and 911 calls. Visit the Neighborhood Table to find your City Council District, Neighborhood Statistical Area, and NPU. This map uses the Weave interactive platform, which allows the user to select data variables and customize related data visualizations (charts/graphs).', 
                   'urls': [ 'https://gisdata.fultoncountyga.gov/datasets/c2e35d6cae3242658b2d44a394c54e7d', 'https://opendata.atlantaregional.com/datasets/c2e35d6cae3242658b2d44a394c54e7d', 'https://hub.arcgis.com/datasets/c2e35d6cae3242658b2d44a394c54e7d']} )
coll.insert_one ( { 'topic':'Atlanta Education', 'fifth dataset': 'ATLANTA EDUCATION FUND INC, fiscal year ending July 2012', 'license': 'NA', 'description': 'ProPublica\'s Nonprofit Explorer lets you view summaries of 2.2 million tax returns from tax-exempt organizations and see financial details such as their executive compensation and revenue and expenses. You can browse raw IRS data released since 2013 and access over 9.4 million tax filing documents going back as far as 2001.', 'urls': [ 'https://projects.propublica.org/nonprofits/organizations/582047710' ] } )
coll.insert_one ( { 'topic':'Atlanta Education', 'sixth dataset': 'City of Atlanta Neighborhood Planning Units (NPU) (Weave Interactive Map)', 'license': 'http://creativecommons.org/licenses/by/4.0', 'description': 'This interactive map, part of the City of Atlanta Data Visualization Suite, displays about 400 indicators for City of Atlanta Neighborhood Planning Units (NPUs). Visit the Neighborhood Table to find your Neighborhood Statistical Area, City Council District, and NPU. The map includes city-specific data such as code enforcement, housing conditions, and 911 calls. The map uses the Weave interactive platform, which allows the user to select data variables and customize related data visualizations (charts/graphs).', 'urls': [ 'http://cloudsopendata2018-02-21t080550470z-be035-clouds.opendata.arcgis.com/datasets/f57f6bd1321344d08aabe25d3ddf0e92', 'https://gisdata.fultoncountyga.gov/datasets/f57f6bd1321344d08aabe25d3ddf0e92', 'https://opendata.atlantaregional.com/datasets/f57f6bd1321344d08aabe25d3ddf0e92' ] } )
coll.insert_one ( { 'topic':'Atlanta Education', 'seventh dataset': 'Bachelor\'s Degree or Higher (5-year estimate) in Carroll County, GA', 'license': 'https://research.stlouisfed.org/fred_terms.html', 'description': 'Graph and download economic data for Bachelor\'s Degree or Higher (5-year estimate) in Carroll County, GA (HC01ESTVC1713045) from 2010 to 2017 about Carroll County, GA; educational attainment; Atlanta; tertiary schooling; GA; education; 5-year; and USA.', 'urls': [ 'https://fred.stlouisfed.org/series/HC01ESTVC1713045' ] } )
coll.insert_one ( { 'topic':'Atlanta Education', 'eighth dataset': 'Bachelor\'s Degree or Higher (5-year estimate) in Barrow County, GA', 'license': 'https://research.stlouisfed.org/fred_terms.html', 'description': 'Graph and download economic data for Bachelor\'s Degree or Higher (5-year estimate) in Barrow County, GA (HC01ESTVC1713013) from 2010 to 2017 about Barrow County, GA; educational attainment; Atlanta; tertiary schooling; GA; education; 5-year; and USA.', 'urls': [ 'https://fred.stlouisfed.org/series/HC01ESTVC1713013' ] } )
coll.insert_one ( { 'topic':'Atlanta Education', 'ninth dataset': 'High School Graduate or Higher (5-year estimate) in Newton County, GA', 'license': 'https://research.stlouisfed.org/fred_terms.html', 'description': 'Graph and download economic data for High School Graduate or Higher (5-year estimate) in Newton County, GA (HC01ESTVC1613217) from 2010 to 2017 about Newton County, GA; educational attainment; secondary schooling; secondary; Atlanta; GA; education; 5-year; and USA.', 'urls': [ 'https://fred.stlouisfed.org/series/HC01ESTVC1613217' ] } )
coll.insert_one ( { 'topic':'Atlanta Education', 'tenth dataset': 'ATLANTA REGIONAL COUNCIL FOR HIGHER EDUCATION, fiscal year ending June 2017', 'license': 'NA', 'description': 'ProPublica\'s Nonprofit Explorer lets you view summaries of 2.2 million tax returns from tax-exempt organizations and see financial details such as their executive compensation and revenue and expenses. You can browse raw IRS data released since 2013 and access over 9.4 million tax filing documents going back as far as 2001.', 'urls': [ 'https://projects.propublica.org/nonprofits/organizations/586002048' ] } )
coll.insert_one ( { 'topic':'Atlanta Education', 'eleventh dataset': 'The Partnership of Business and Education : Remarks to the Atlanta Employers\' Merit Employment Association', 'license': 'NA', 'description': 'Statements and Speeches of Robert P. Forrestal, The Partnership of Business and Education : Remarks to the Atlanta Employers\' Merit Employment Association by Robert P. Forrestal, Federal Reserve Bank of Atlanta', 'urls': [ 'https://fraser.stlouisfed.org/title/5169/item/521095' ] } )
coll.insert_one ( { 'topic':'Atlanta Education', 'twelfth dataset': 'Consumer Price Index: Education and Communication in Atlanta-Sandy Springs-Roswell, GA, All Urban Consumers', 'license': 'https://research.stlouisfed.org/fred_terms.html', 'description': 'Graph and download economic data for Consumer Price Index: Education and Communication in Atlanta-Sandy Springs-Roswell, GA, All Urban Consumers (CUURA319SAE) from Dec 1997 to Aug 2019 about communication, Atlanta, GA, education, urban, consumer, CPI, inflation, price index, price, indexes, and USA.', 'urls': [ 'https://fred.stlouisfed.org/series/CUURA319SAE/?utm_source=rss&utm_medium-rss&utm_campaign=fred-updates' ] } )
coll.insert_one ( { 'topic':'Atlanta Education', 'thirteenth dataset': 'Consumer Price Index: Education and Communication in Atlanta-Sandy Springs-Roswell, GA, All Urban Consumers', 'license': 'https://research.stlouisfed.org/fred_terms.html', 'description': 'Graph and download economic data for Consumer Price Index: Education and Communication in Atlanta-Sandy Springs-Roswell, GA, All Urban Consumers (CUUSA319SAE) from H1 1998 to H1 2019 about communication, Atlanta, GA, education, urban, consumer, CPI, inflation, price index, price, indexes, and USA.', 'urls': [ 'https://fred.stlouisfed.org/series/CUUSA319SAE' ] } )
coll.insert_one ( { 'topic':'Atlanta Education', 'fourteenth dataset': 'People 25 Years and Over Who Have Completed an Associate\'s Degree or Higher (5-year estimate) in Fulton County, GA', 'license': 'https://research.stlouisfed.org/fred_terms.html', 'description': 'Graph and download economic data for People 25 Years and Over Who Have Completed an Associate\'s Degree or Higher (5-year estimate) in Fulton County, GA (S1501ACSTOTAL013121) from 2009 to 2017 about advanced degree; Fulton County, GA; associate degree; educational attainment; Atlanta; 25 years +; tertiary schooling; persons; GA; education; 5-year; Prosperity Scorecard; and USA.', 'urls': [ 'https://fred.stlouisfed.org/series/S1501ACSTOTAL013121' ] } )
coll.insert_one ( { 'topic':'Atlanta Education', 'fifteenth dataset': 'Atlanta Journal-Constitution/WSB-TV Poll: Education in Metro-Atlanta', 'license': 'NA', 'description': 'This survey covers the following issues and topics: Asked of Parents: Rating of local schools (6); minority students (3); selected child\'s educational experience, homework, television, bedtime (9); racial attitudes and education (10). Asked of Children: Rating of local schools (2); friendship with students of a different race (6); racial attitudes and education (6); weekly allowance and chores (8).', 'urls': [ 'https://datamed.org/display-item.php?repository=0012&idName=ID&id=56d4b7dde4b0e644d312c593' ] } )
coll.insert_one ( { 'topic':'Atlanta Education', 'sixteenth dataset': 'Educational Attainment (by Zip Code) 2015', 'license': 'http://creativecommons.org/licenses/by/4.0/', 'description': '', 'urls': [ '' ] } )
coll.insert_one ( { 'topic':'Atlanta Education', 'seventeenth dataset': 'The Atlanta Region\'s Plan Employment Forecasts by Sector (series 15 : 2015-2040)', 'license': 'http://creativecommons.org/licenses/by/4.0', 'description': 'This layer was developed by the Research & Analytics Division of the Atlanta Regional Commission from ARC\'s Regional Plan Update to represent employment forecasts by census tract for the Atlanta region. The Atlanta Region\'s Plan forecast was formally adopted by the ARC Board on February 24, 2016.', 'urls': [ 'https://arc-garc.opendata.arcgis.com/datasets/54a6e30fc6554335a0e041cb723429e4_192/geoservice', 'https://opendata.atlantaregional.com/datasets/54a6e30fc6554335a0e041cb723429e4_192/geoservice', 'http://maps.torontopolice.on.ca/items/54a6e30fc6554335a0e041cb723429e4', 'https://gisdata.fultoncountyga.gov/datasets/54a6e30fc6554335a0e041cb723429e4_192' ] } )
coll.insert_one ( { 'topic':'Atlanta Education', 'eighteenth dataset': 'Educational Attainment 2015 (Senate Districts)', 'license': 'http://creativecommons.org/licenses/by/4.0', 'description': 'This layer was developed by the Research & Analytics Group of the Atlanta Regional Commission, using data from American Community Survey 5-year estimates for 2011-2015 to show level of education completed, by state Senate district for the state of Georgia.\nThe user should note that American Community Survey data represent estimates derived from a surveyed sample of the population, which creates some level of uncertainty, as opposed to an exact measure of the entire population (the full census count is only conducted once every 10 years and does not cover as many detailed characteristics of the population). Therefore, any measure reported by ACS should not be taken as an exact number. ACS data presented here represent combined 5-year estimates, meaning these estimates represent rolling averages of survey results that were collected over a 5-year span (in this case 2011-2015). Therefore, these data do not represent any one specific point in time or even one specific year. For further explanation of ACS estimates and methodology, click here.', 
                   'urls': [ 'https://opendata.atlantaregional.com/datasets/e8e47261439a42c5919061934a47a9a6_344', 'https://gisdata.fultoncountyga.gov/datasets/e8e47261439a42c5919061934a47a9a6_344', 'https://arc-garc.opendata.arcgis.com/datasets/e8e47261439a42c5919061934a47a9a6_344' ] } )
coll.insert_one ( { 'topic':'Atlanta Education', 'nineteenth dataset': 'People 25 Years and Over Who Have Completed an Associate\'s Degree or Higher (5-year estimate) in Cobb County, GA', 'license': 'https://research.stlouisfed.org/fred_terms.html', 'description': 'Graph and download economic data for People 25 Years and Over Who Have Completed an Associate\'s Degree or Higher (5-year estimate) in Cobb County, GA (S1501ACSTOTAL013067) from 2009 to 2017 about Cobb County, GA; advanced degree; associate degree; educational attainment; Atlanta; 25 years +; tertiary schooling; persons; GA; education; 5-year; Prosperity Scorecard; and USA.', 'urls': [ 'https://fred.stlouisfed.org/series/S1501ACSTOTAL013067' ] } )
coll.insert_one ( { 'topic':'Atlanta Education', 'twentieth dataset': 'High School Graduate or Higher (5-year estimate) in Butts County, GA', 'license': 'https://research.stlouisfed.org/fred_terms.html', 'description': 'Graph and download economic data for High School Graduate or Higher (5-year estimate) in Butts County, GA (HC01ESTVC1613035) from 2010 to 2017 about Butts County, GA; educational attainment; secondary schooling; secondary; Atlanta; GA; education; 5-year; and USA.', 'urls': [ 'https://fred.stlouisfed.org/series/HC01ESTVC1613035' ] } )

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['dsuarez1']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d884beaba8cb38cb0776753'),
#  'description': 'Graph and download economic data for All '
#                 'Employees: Educational Services in '
#                 'Atlanta-Sandy Springs-Roswell, GA (MSA) '
#                 '(SMU13120606561000001SA) from Jan 1990 to Jul '
#                 '2019 about Atlanta, GA, education, services, '
#                 'employment, and USA.',
#  'first dataset': 'All Employees: Educational Services in '
#                   'Atlanta-Sandy Springs-Roswell, GA (MSA)',
#  'license': 'https://research.stlouisfed.org/fred_terms.html',
#  'topic': 'Atlanta Education',
#  'urls': ['https://fred.stlouisfed.org/series/SMU13120606561000001SA']}
# {'_id': ObjectId('5d884beaba8cb38cb0776754'),
#  'description': 'Graph and download economic data for '
#                 "Bachelor's Degree or Higher (5-year estimate) "
#                 'in Clayton County, GA (HC01ESTVC1713063) from '
#                 '2010 to 2017 about Clayton County, GA; '
# ...
