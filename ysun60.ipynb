# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['ysun60']
# for each dataset
coll.insert_one ( { 'topic':'IMDB dataset', 'title': 'IMDB 5000 Movie Dataset', 'license': 'other', 'description': 'The list of movie data', 'urls': [ 'https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset#movie_metadata.csv'] } )
coll.insert_one ( { 'topic':'IMDB dataset', 'title': 'IMDB Movie Reviews Dataset', 'license': 'other', 'description': 'The list of movie data', 'urls': [ 'https://www.kaggle.com/iarunava/imdb-movie-reviews-dataset'] } )
coll.insert_one ( { 'topic':'IMDB dataset', 'title': 'IMDB 5000 Movie Dataset', 'license': 'other', 'description': 'The list of movie data', 'urls': ['https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset'] } )
coll.insert_one ( { 'topic':'IMDB dataset', 'title': 'IMDB Dataset of 50K Movie Reviews', 'license': 'other', 'description': 'The list of movie data', 'urls': ['https://www.kaggle.com/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews'] } )
coll.insert_one ( { 'topic':'IMDB dataset', 'title': 'IMDB data from 2006 to 2016', 'license': 'other', 'description': 'The list of movie data', 'urls': ['https://www.kaggle.com/PromptCloudHQ/imdb-data'] } )
coll.insert_one ( { 'topic':'IMDB dataset', 'title': 'IMDB Review Dataset', 'license': 'CC0: Public Domain', 'description': 'The list of movie data', 'urls': ['https://www.kaggle.com/utathya/imdb-review-dataset'] } )
coll.insert_one ( { 'topic':'IMDB dataset', 'title': 'Top rated English movies of this decade from IMDB', 'license': 'other', 'description': 'The list of movie data', 'urls': ['https://data.world/saipranav/top-rated-english-movies-of-this-decade-from-imdb'] } )
coll.insert_one ( { 'topic':'IMDB dataset', 'title': 'Data title', 'license': 'other', 'description': 'The list of movie data', 'urls': ['https://www.kaggle.com/rmisra/imdb-spoiler-dataset'] } )
coll.insert_one ( { 'topic':'IMDB dataset', 'title': 'IMDB Spoiler Dataset', 'license': 'CC0: Public Domain', 'description': 'The list of movie data', 'urls': ['https://data.world/popculture/imdb-5000-movie-dataset'] } )
coll.insert_one ( { 'topic':'IMDB dataset', 'title': 'IMDB 5000 Movie Dataset', 'license': 'other', 'description': 'The list of movie data', 'urls': ['https://www.kaggle.com/pkabir/imdb-movie-ratings'] } )
coll.insert_one ( { 'topic':'IMDB dataset', 'title': 'IMDB movie ratings', 'license': 'CC0: Public Domain', 'description': 'The list of movie data', 'urls': ['https://www.kaggle.com/tudor9/movie-reviews-imdb'] } )
coll.insert_one ( { 'topic':'IMDB dataset', 'title': 'Movie reviews IMDB', 'license': 'other', 'description': 'The list of movie data', 'urls': ['https://www.kaggle.com/adnanr94/imdb-movies-metadata'] } )
coll.insert_one ( { 'topic':'IMDB dataset', 'title': 'IMDB Top 250 Lists and 5000 plus IMDB records', 'license': 'CC0: Public Domain', 'description': 'The list of movie data', 'urls': ['https://data.world/studentoflife/imdb-top-250-lists-and-5000-or-so-data-records'] } )
coll.insert_one ( { 'topic':'IMDB dataset', 'title': 'The Movies Dataset', 'license': 'other', 'description': 'The list of movie data', 'urls': ['https://www.kaggle.com/rounakbanik/the-movies-dataset'] } )
coll.insert_one ( { 'topic':'IMDB dataset', 'title': 'IMDb Movie Reviews', 'license': 'Data files © Original Authors', 'description': 'The list of movie data', 'urls': ['https://www.kaggle.com/luisfredgs/imdb-movie-reviews'] } )
coll.insert_one ( { 'topic':'IMDB dataset', 'title': 'IMDB Synopsis Indonesian Movies', 'license': 'other', 'description': 'The list of movie data', 'urls': ['https://www.kaggle.com/antoniuscs/imdb-synopsis-indonesian-movies'] } )
coll.insert_one ( { 'topic':'IMDB dataset', 'title': 'imdb dataset', 'license': 'other', 'description': 'The list of movie data', 'urls': ['https://www.kaggle.com/lianglirong/imdb-dataset'] } )
coll.insert_one ( { 'topic':'IMDB dataset', 'title': 'Latest IMDB', 'license': 'CC0: Public Domain', 'description': 'The list of movie data', 'urls': ['https://www.kaggle.com/adityaecdrid/latest-imdb'] } )
coll.insert_one ( { 'topic':'IMDB dataset', 'title': 'imdb', 'license': 'other', 'description': 'The list of movie data', 'urls': ['https://old.datahub.io/dataset/imdb@2008-01-18T19:06:43'] } )
coll.insert_one ( { 'topic':'IMDB dataset', 'title': 'Movie IMDB', 'license': 'Data files © Original Authors', 'description': 'The list of movie data', 'urls': ['https://www.kaggle.com/kevalm/movie-imdb'] } )

pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d8194bbd4732fb4def48114'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'IMDB dataset',
#  'urls': ['https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset#movie_metadata.csv']}
# {'_id': ObjectId('5d8194d5d4732fb4def48117'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'IMDB dataset',
#  'urls': ['https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset#movie_metadata.csv']}
# {'_id': ObjectId('5d819564d4732fb4def48119'),
#  'description': 'The list of movie data',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'IMDB dataset',
#  'urls': ['https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset#movie_metadata.csv']}
# {'_id': ObjectId('5d84624fd4732fb4def4811c'),
# ...

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['ysun60']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d8194bbd4732fb4def48114'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'IMDB dataset',
#  'urls': ['https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset#movie_metadata.csv']}
# {'_id': ObjectId('5d8194d5d4732fb4def48117'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'IMDB dataset',
#  'urls': ['https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset#movie_metadata.csv']}
# {'_id': ObjectId('5d819564d4732fb4def48119'),
#  'description': 'The list of movie data',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'IMDB dataset',
#  'urls': ['https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset#movie_metadata.csv']}
# {'_id': ObjectId('5d84624fd4732fb4def4811c'),
# ...
