# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['audris']
# for each dataset
coll.insert_one ( { 'topic':'git URLs', 'first dataset': 'largest projects', 'license': 'NA', 'description': 'The list of projects on github with the largest number of starts', 'urls': [ 'url1', 'url2' ] } )
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   # This is added back by InteractiveShellApp.init_path()
# ObjectId('5d7e6769e1eaff62f15de0d2')

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['audris']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d7e6769e1eaff62f15de0d2'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
#  'urls': ['url1', 'url2']}
# {'_id': ObjectId('5d7edc7c995d246453e1025b'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
#  'urls': ['url1', 'url2']}
# {'_id': ObjectId('5d81827493569c62818e7979'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
#  'urls': ['url1', 'url2']}
# {'_id': ObjectId('5d8193ebd4732fb4def4810e'),
#  'description': 'The list of projects on github with the '
#                 'largest number of starts',
#  'first dataset': 'largest projects',
# ...

# %%
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['zcole5']
# for each dataset
coll.insert ( { 'topic':'Star Wars', 'title': 'Star Wars Movie Scripts', 'license': 'Open Database License (ODbL) v1.0', 'description': 'The scraped scripts from the original 6 movies', 'urls': [ 'https://www.kaggle.com/xvivancos/star-wars-movie-scripts' ] } )
coll.insert ( { 'topic':'Star Wars', 'title': 'Star Wars', 'license': 'N/A', 'description': 'Data on characters, planet, species, starships, and vehicles', 'urls': [ 'https://www.kaggle.com/jsphyg/star-wars' ] } )
coll.insert ( { 'topic':'Star Wars', 'title': 'Yoda Speech Corpus', 'license': 'CC BY-NC-SA 4.0', 'description': 'A collection of all of Yodas lines', 'urls': [ 'https://www.kaggle.com/stefanocoretta/yoda-speech-corpus' ] } )
coll.insert ( { 'topic':'Star Wars', 'title': 'Star Wars Steganography Images', 'license': 'N/A', 'description': 'Different Steganography Images', 'urls': [ 'https://www.kaggle.com/valkling/star-wars-steganography-images' ] } )
coll.insert ( { 'topic':'Star Wars', 'title': 'Star Wars Movie Dialogues: Segmented by Scene', 'license': 'N/A', 'description': 'The actual Dialogue for movies 2-6', 'urls': [ 'https://www.kaggle.com/kunyuhe/star-wars-movie-dialogues-segmented-by-scene' ] } )
coll.insert ( { 'topic':'Star Wars', 'title': 'Star Wars social network', 'license': 'N/A', 'description': 'Connecting the characters by interation with one another', 'urls': [ 'https://zenodo.org/record/1411479#.XYgVLihKhPY' ] } )
coll.insert ( { 'topic':'Star Wars', 'title': 'Star Wars Fans Survey', 'license': 'N/A', 'description': 'A survey that provides global data on star wars fans', 'urls': [ 'http://hub.arcgis.com/datasets/083c5284861d403d80a0bdb964eb6372' ] } )
coll.insert ( { 'topic':'Star Wars', 'title': 'Revenue and profit generated by Disneys Star Wars sequel trilogy and Anthology Series worldwide from 2015 to 2019 (in billion U.S. dollars)', 'license': 'NA', 'description': 'Moeny Data', 'urls': [ 'https://www.statista.com/statistics/498916/revenue-profit-disney-star-wars-sequel-anthology/' ] } )
coll.insert ( { 'topic':'Star Wars', 'title': 'Highest grossing film franchises and series worldwide as of March 2019 (in billion U.S. dollars)', 'license': 'NA', 'description': 'Where star wars sits compared to other film franchises', 'urls': [ 'https://www.statista.com/statistics/317408/highest-grossing-film-franchises-series/' ] } )
coll.insert ( { 'topic':'Star Wars', 'title': 'Box office revenue of the Star Wars movies in North America from 1977 to 2018 (in million U.S. dollars)', 'license': 'NA', 'description': 'Revenue from Star Wars in North America', 'urls': [ 'https://static1.statista.com/statistics/790354/star-wars-domestic-box-office-revenue/' ] } )
coll.insert ( { 'topic':'Star Wars', 'title': 'Production costs and global box office revenue of Star Wars movies from 1977 to 2018 (in million U.S. dollars)', 'license': 'NA', 'description': 'Production cost vs Revenue for all the movies', 'urls': [ 'https://www.statista.com/statistics/311356/star-wars-production-costs-box-office-revenue/' ] } )
coll.insert ( { 'topic':'Star Wars', 'title': 'Biggest opening weekends at the North American box office as of July 2019, by revenue (in million U.S. dollars)', 'license': 'NA', 'description': 'Comparison of opening weekend of some star wars movies to other box office hits', 'urls': [ 'https://static1.statista.com/statistics/188498/biggest-opening-weekends-at-the-north-american-box-office/' ] } )
coll.insert ( { 'topic':'Star Wars', 'title': 'Domestic box office revenue of the most successful movies of all time as of September 2019 (in million U.S. dollars)', 'license': 'NA', 'description': 'Comparison of Star Wars to other most successful movies', 'urls': [ 'https://static1.statista.com/statistics/187405/box-office-revenue-of-the-top-grossing-movies-in-north-america-2005/' ] } )
coll.insert ( { 'topic':'Star Wars', 'title': 'Who is you favorite Star Wars character?', 'license': 'NA', 'description': 'A vote of the favorite characters', 'urls': [ 'https://static1.statista.com/statistics/305215/star-wars-favorite-character-usa/' ] } )
coll.insert ( { 'topic':'Star Wars', 'title': 'Most popular movie nominees at the Academy Awards 2017, by social media actions', 'license': 'NA', 'description': 'Comparing Rogue One to other nominees for Academy Awards', 'urls': [ 'https://static1.statista.com/statistics/321216/online-buzz-popular-best-picture-twitter-numbers-academy-awards/' ] } )
coll.insert ( { 'topic':'Star Wars', 'title': 'Movies with the most Facebook fans as of September 2019 (in millions)', 'license': 'NA', 'description': 'Comparing Star Wars to other movies with the most fans on facebook', 'urls': [ 'https://static1.statista.com/statistics/271381/most-popular-movies-on-facebook-based-on-number-of-fans/' ] } )
coll.insert ( { 'topic':'Star Wars', 'title': 'Box office revenue of Solo: A Star Wars Story in selected territories worldwide in 2018 (in million U.S. dollars)', 'license': 'NA', 'description': 'Star Wars revenure in the US compared to other countries', 'urls': [ 'https://static1.statista.com/statistics/942031/solo-a-star-wars-story-box-office-revenue/' ] } )
coll.insert ( { 'topic':'Star Wars', 'title': 'Star Wars Survey', 'license': 'CC-BY', 'description': 'Another Star Wars survey', 'urls': [ 'https://data.world/fivethirtyeight/star-wars-survey' ] } )
coll.insert ( { 'topic':'Star Wars', 'title': 'star-wars-dataset', 'license': 'N/A', 'description': 'GitHub repo of Star Wars Data', 'urls': [ 'https://github.com/fgeorges/star-wars-dataset/blob/master/data/enriched.json' ] } )
coll.insert ( { 'topic':'Star Wars', 'title': 'swapi', 'license': 'N/A', 'description': 'An actual Star Wars dataset website', 'urls': [ 'https://swapi.co/' ] } )
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# ...

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac19mp2']
coll = db ['zcole5']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find():
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d880b4913eede918ea50ad3'),
#  'description': 'A collection of different Star Wars datasets',
#  'license': 'license',
#  'title': 'Different Star Wars Datasets',
#  'topic': 'Star Wars',
#  'urls': ['url1', 'url2']}
# {'_id': ObjectId('5d88244a13eede918ea50ad7'),
#  'description': 'A collection of different Star Wars datasets',
#  'license': 'Open Database License (ODbL) v1.0',
#  'title': 'Different Star Wars Datasets',
#  'topic': 'Star Wars',
#  'urls': ['https://www.kaggle.com/xvivancos/star-wars-movie-scripts']}
# {'_id': ObjectId('5d88244a13eede918ea50ad8'),
#  'description': 'A collection of different Star Wars datasets',
#  'license': 'N/A',
#  'title': 'Different Star Wars Datasets',
#  'topic': 'Star Wars',
#  'urls': ['https://www.kaggle.com/jsphyg/star-wars']}
# {'_id': ObjectId('5d88244a13eede918ea50ad9'),
#  'description': 'A collection of different Star Wars datasets',
#  'license': 'CC BY-NC-SA 4.0',
#  'title': 'Different Star Wars Datasets',
# ...
